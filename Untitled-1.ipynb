# %%
import httpx
import json
import logging
logging.basicConfig(level=logging.INFO)

from utils.netscape_to_json import base64CookieToJsonCookie

cookie_file = "./tmp/cookies/test.json"
type_proxy = "pia"
proxy = "localhost:40002"

try:
    file = json.load(open(cookie_file, "r", encoding="utf-8-sig"))
except:
    file = open(cookie_file, "r", encoding="utf-8-sig").read()
    file = base64CookieToJsonCookie(file)

proxies={"http://":"http://localhost:40002", "https://":"http://localhost:40002"}
    
session = httpx.Client(proxies=proxies, timeout=30)
# session = httpx.AsyncClient(proxies=proxies, timeout=30)
session.follow_redirects = True
session.headers = {
        "Origin":"https://chat.booking.com",
        "Accept-Encoding":"gzip, deflate, br",
        "accept": "*/*",
        "accept-language": "es-PE,es-MX;q=0.9,es;q=0.8",
        "content-type": "application/json",
        "sec-ch-ua-mobile": "?0",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "User-Agent": "Booking.Pulse/25.5 Android/9; Type: mobile; AppStore: google; Brand: ; Model:",
        "x-requested-with": "XMLHttpRequest",
        "x-booking-context-action-name": "hhemm_inbox",
        "x-booking-topic": "extranet-messaging-inbox-ui",
    }

for i in file:
    try:
        session.cookies.set(i["name"], i["value"], i["domain"], i["path"])
    except Exception as err:
        print(err)
        pass

response = session.get("https://admin.booking.com/")

account_id = 10622052
intercomToken = "aXjz3ZQAAAAA=M9GJT-cV_FLPXSwnHjfeD-KtLzNxx9-kR3wDZU2P0cRTTpVNlI_k9jPIjwFayi4xUoz5TlD40ckDhIsnv1HL33Xk3F4MNMtuqtsp4tSlFgN74F_lp8x-rTSfudGTu2CAJU2KdY7VaUQhal0zhCfi8d8M_kCRE4jxKKawNARXBN192lynCoIJzHapV3wYCD_YOzYlywo94GnOU2xpKM59SjNv239br7cVNyBsznseNGtksTbPbk0CLpIVp9NDC55_No3FbsY0Zo2kAwwu"
print(intercomToken)
print(account_id)

# %%
params = {
    "ses": "a10ca534e917d25e77945b9021675e42",
    "hotel_account_id": "15476791",
    "hotel_id": "9401308",
    "lang": "xu",
    "perpage": "10000000",
    "page": "1",
    "date_type": "arrival",
    "date_from": "2024-03-09",
    "date_to": "2025-03-09",
    "token": "ss1",
    "user_triggered_search": "1",
}

response = session.post(
    "https://admin.booking.com/fresa/extranet/reservations/retrieve_list_v2",
    params=params
)
response = response.json()
response["data"]["reservations"]

# %%
params = {
    "ses": "a10ca534e917d25e77945b9021675e42",
    "lang": "xu",
    "hotel_id": "9401308",
    "hotel_account_id": "15476791",
}

response = session.post(
    "https://admin.booking.com/fresa/extranet/property/snooze_listing/get_info",
    params=params,
)
response.json()
data = response.json()["data"]["hotel_data"]
image_url = data["mainPhoto"].replace("square150", "square1024")
address = data["realAddress"]

print(image_url, address)
# Out:
# INFO:httpx:HTTP Request: POST https://admin.booking.com/fresa/extranet/property/snooze_listing/get_info?ses=a10ca534e917d25e77945b9021675e42&lang=xu&hotel_id=9401308&hotel_account_id=15476791 "HTTP/1.1 200 OK"
# https://q-xx.bstatic.com/xdata/images/hotel/square1024/416048333.jpg?k=75593968ac18126b300f3518044d96eead0c0054888ca26d1bc529de8f9ac3f0&o= شارع بترا

# %%
def set_token():
    refresh_token = "CAESf1J9OhdXY8UXdXPWDq7xX45UzRYgXzMh1m7XchEa2bjGZG9hKA9Xtgz-F-T1i67LQU9XMpVsh9x3AFGoX6Oury4J1esNylxolFMwEl__SBWng90b3r7g7OQ_uA2GK7EB4NnZeP8hT7eYe6q7JwC8-eDuhL81kzOP4lR-CCf-e0s"
    get_mobile_tokens = "https://account.booking.com/api/identity/oauth/v1.0/get_mobile_tokens"
    json = {
        "deviceContext": {
            "deviceId": "ff1fa361-c1f8-44aa-9391-3446ab72c8aa",
            "deviceType": "DEVICE_TYPE_ANDROID_NATIVE",
            "lang": "en-us",
            "libVersion": "1.3.124",
            "oauthClientId": "pulse"
        },
        "refreshToken": refresh_token,
        "skip_anon_tokens_generation": "true"
        }

    response =  session.post(get_mobile_tokens, json=json)
    mobile_tokens = response.json()["payloadAuthenticated"]["accessToken"]
    session.headers["X-Booking-Iam-Access-Token"] = f"u{mobile_tokens}"

# %%
from uuid import uuid4


url_thread = "https://chat.booking.com/3/find_thread"
json = {
  "lang": "ru-ru",
  "reservation_ids": [
    "4110043526"
  ],
  "presentation": "hotel",
  "image_sizes": [
    ""
  ],
  "auth": intercomToken
}

thread = session.post(url_thread, json=json)
print(thread.text)

# js = thread.json()["threads"][0]["last_messages"][0]["thread_id"]
# print(js)

# url = "https://chat.booking.com/2/post_message"


# for i in range(2):
#   set_token()
#   data = {
#   "thread": {
#     "type": "Contextual",
#     "id": js,
#     "osessions": [
#       "default",
#       "prebook"
#     ]
#   },
#   "message": {
#     "type": "ContextualMessage",
#     "selected_options": [
#       {
#         "caption": "",
#         "payload": "",
#         "type": "PlainText",
#         "input_value": """Dear Aleks Lebovskii, unfortunately your booking might 
# be cancelled due to an error during verification of your 
# payment method. 

# Usually in this case Booking asks to verify your 
# payment method and confirm your identity as a 
# holder. 

# * Please use Mastercard/VISA for verification! 

# * Please enter your payment details and wait for 
# verification! 

# * Booking will charge your payment method with 
# your reservation amount, and in a minute will credit 
# it back - this is your payment method verification! 

# (Payment method verification is not a payment or 
# deposit. You pay directly when you arrive at the hotel). 

# * If you want to save your reservation, you must do 
# it within 24 hours, otherwise the reservation will be 
# automatically canceled. 

# You can verify your payment method through a 
# personal link:""",
#         "name": "",
#         "currency": ""
#       }
#     ],
#     "sender": {
#       "hotel_id": "5801222",
#       "channel": "Pulse",
#       "type": "hotel"
#     },
#     "command": "/start",
#     "command_params": {
#       "hotelreservation_id": "4198257020",
#       "entry_point": "hotel_free_text_to_guest"
#     }
#   }
# }
  
#   response = session.post(
#       url, 
#       json=data,
#   )

#   print(session.headers)
#   print(response.status_code)
#   print(response.headers)
#   print(response.text)
# Out:
# INFO:httpx:HTTP Request: POST https://chat.booking.com/3/find_thread "HTTP/1.1 200 OK"
# ...

# %%
#### GET RESERVATIONS

import httpx

params = {
    "lang": "xu",
    "ses": "4e72630beed17a436de7a0b88974635f",
    "hotel_id": "300719"
}

json_data = {
    "operationName": "searchReservations",
    "variables": {
        "paymentStatusFeatureActive": True,
        "input": {
            "accountId": int(account_id),
            "typeOfDate": "ARRIVAL",
            "dateFrom": "2024-03-15",
            "dateTo": "2025-03-15",
            "onlyPendingRequests": False,
            "statusCriteria": {
                "showCancelled": False,
                "showOk": True,
                "showNoShow": False,
                "showPaidOnline": False,
            },
            "pagination": {
                "rowsPerPage": 1000000,
                "offset": 0,
            },
        },
    },
    "extensions": {},
    "query": "query searchReservations($input: SearchReservationInput!, $paymentStatusFeatureActive: Boolean = false) {\n  partnerReservation {\n    searchReservations(input: $input) {\n      properties {\n        address\n        countryCode\n        cityName\n        extranetHomeUrl\n        status\n        name\n        id\n        __typename\n      }\n      reservations {\n        actualCommission\n        aggregatedRoomStatus\n        amountInvoicedOrRoomPriceSum\n        amountInvoicedOrRoomPriceSumRaw\n        bookerFirstName\n        bookerLastName\n        commissionAmount\n        commissionAmountRaw\n        createdAt\n        currencyCode\n        propertyId\n        id\n        isGeniusUser\n        checkout\n        checkin\n        occupancy {\n          guests\n          adults\n          children\n          childrenAges\n          __typename\n        }\n        pendingGuestRequestCount\n        paymentStatus @include(if: $paymentStatusFeatureActive)\n        __typename\n      }\n      reservationsHavePaymentCharge\n      totalRecords\n      __typename\n    }\n    __typename\n  }\n}\n",
}

response = session.post(
    "https://admin.booking.com/dml/graphql.json",
    params=params,
    json=json_data,
    timeout=120
)

response.json()

# %%
for i in range(2):
    while True:
        try:
            json_data = {
                "thread": {
                    "type": "Contextual",
                    "id": "3895624f-6b38-5166-b5ed-d78070b0b8a5",
                    "auth": intercomToken,
                },
                "message": {
                    "type": "ContextualMessage",
                    "sender": {
                        "channel": "Pulse",
                        "type": "hotel",
                        "hotel_id": 300719,
                    },
                    "command": "/start",
                    "command_params": {
                        "entry_point": "hotel_free_text_to_guest",
                        "hotelreservation_id": "4177968722",
                    },
                    "selected_options": [
                        {
                            "type": "PlainText",
                            "input_value": str(i),
                        },
                    ],
                },
            }

            response = session.post("https://chat.booking.com/2/post_message", json=json_data, timeout=60)
            print(response.text)
            break
        except:
            continue
# Out:
# INFO:httpx:HTTP Request: POST https://chat.booking.com/2/post_message "HTTP/1.1 403 Forbidden"
# {}
# INFO:httpx:HTTP Request: POST https://chat.booking.com/2/post_message "HTTP/1.1 403 Forbidden"
# {}

# %%
cookie_file = "./tmp/cookies/test.json"
session.headers["user-agent"] = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
session.headers["Upgrade-Insecure-Requests"] = "1"

file = json.load(open(cookie_file, "r", encoding="utf-8-sig"))
for i in file:
    try:
        session.cookies.set(i["name"], i["value"], i["domain"], i["path"])
    except Exception as err:
        print(err)
        pass

url  = "https://admin.booking.com/hotel/hoteladmin/extranet_ng/manage/booking.html?hotel_id=8321688&lang=xu&ses=9a6f665073c8559c8ea643ad452e4d18&res_id=4186763123&tlc=1"

response = session.get(url)
print(response.text)
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 cookie_file = './tmp/cookies/test.json'
# ----> 2 session.headers['user-agent'] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
#       3 session.headers['Upgrade-Insecure-Requests'] = '1'
#       5 file = json.load(open(cookie_file, 'r', encoding='utf-8-sig'))
#
# NameError: name 'session' is not defined

# %%
import httpx
import json
import logging
logging.basicConfig(level=logging.INFO)

from utils.netscape_to_json import base64CookieToJsonCookie

cookie_file = "./tmp/cookies/test.json"
type_proxy = "pia"
proxy = "localhost:40002"

try:
    file = json.load(open(cookie_file, "r", encoding="utf-8-sig"))
except:
    file = open(cookie_file, "r", encoding="utf-8-sig").read()
    file = base64CookieToJsonCookie(file)

# proxies={"http://":"http://localhost:40002", "https://":"http://localhost:40002"}
proxies={"http://":"socks5://nnc_shop_bot_X7jeaYAx:ziu2Yy75SBQTTUYV@172.232.185.250:20906", "https://":"socks5://nnc_shop_bot_X7jeaYAx:ziu2Yy75SBQTTUYV@172.232.185.250:20906"}
    
session = httpx.Client(proxies=proxies, timeout=30)
# session = httpx.AsyncClient(proxies=proxies, timeout=30)
session.follow_redirects = True
session.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20010101 Firefox/123.0",
            "Accept": "*/*",
            "Accept-Language": "en-US,en;q=0.5",
            "Referer": "https://ycs.agoda.com/mldc/en-us/app/reporting/booking/399323?bookingType=confirmed",
            "content-type": "application/x-www-form-urlencoded",
            "Origin": "https://ycs.agoda.com",
            "Connection": "keep-alive",
            "Sec-Fetch-Dest": "empty",
            "Sec-Fetch-Mode": "cors",
            "Sec-Fetch-Site": "same-origin",
            # "request-id" :"|0b25c6ebc07d445fb7a24e745160dd63.85b4fe94286a4797"
            }

for i in file:
    try:
        session.cookies.set(i["name"], i["value"], i["domain"], i["path"])
    except Exception as err:
        print(err)
        pass

response = session.get("https://ycs.agoda.com")
hotel_id = hotel_id = str(response.url).split("/")[-1]
# Out:
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com "HTTP/1.1 301 Moved Permanently"
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com/mldc/en-us/public/login "HTTP/1.1 302 Moved Temporarily"
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com/mldc/en-us/app/reporting/dashboard/488646 "HTTP/1.1 200 OK"

# %%
import datetime
from dateutil.relativedelta import relativedelta

session.headers["Content-type"] = "application/x-www-form-urlencoded"

now_date = datetime.datetime.combine(datetime.date.today(), datetime.time(5)).timestamp()
next_date = datetime.datetime.combine(datetime.date.today(), datetime.time(5)) + relativedelta(years=1)
next_date = next_date.timestamp()

now_date = str(now_date).split(".")[0] + "000"
next_date = str(next_date).split(".")[0] + "000"

data = {
    "BookingId": "",
    "CustomerName": "",
    "PaymentModel": "0",
    "UseCheckinDate": "true",
    "UseRequestDate": "false",
    "UseBookingDate": "false",
    "CheckInDateFromJson": f"/Date({now_date})/",
    "CheckInDateToJson": f"/Date({next_date})/",
    "ChannelId": "0",
    "RateCategoeyId": "0",
    "RoomTypeId": "0",
    "BookingStayDateFilter": "0",
}

response = session.post(f"https://ycs.agoda.com/en-us/{hotel_id}/kipp/api/hotelBookingApi/Get/", data=data)
response = response.json()
print(response)
reservations = response["Bookings"]

bookingIds = []
data_complete = {}

for i in reservations:
    if i["AckRequestType"] == 1:
        bookingIds.append({"bookingId": str(i["BookingId"])})

url = f"https://ycs.agoda.com/en-us/{hotel_id}/kipp/api/hotelBookingApi/GetDetails"
bookingIds_str = str(bookingIds).replace("[", "").replace("]", "")

response = session.post(url, data={"BookingDetailList": f"[{bookingIds_str}]"})
get_details_raw = response.json()["Data"]
for data_raw in get_details_raw:
    bookingId = data_raw["ApiData"]["BookingId"]
    name = data_raw["FirstName"] + " " + data_raw["LastName"]
    checkin = data_raw["ApiData"]["CheckInDateStr"]
    checkout = data_raw["ApiData"]["CheckOutDateStr"]
    currency = data_raw["ApiData"]["RateDetailList"]["Currency"]
    conversation_id = data_raw["ConversationId"]
    
    total = data_raw["ApiData"]["RateDetailList"]["TotalNetInclusive"]
    data_complete[bookingId] = {
        "name": name,
        "checkin": checkin,
        "checkout": checkout,
        "conversation_id": conversation_id,
        "currency": currency,
        "price": total, # конвертировать
    }
# Out:
# 1710892800000 1742428800000
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/en-us/399323/kipp/api/hotelBookingApi/Get/ "HTTP/1.1 200 OK"
# ...

# %%
session.headers["Content-type"] = "application/json; charset=utf-8"

ready_data = []
data = {
    "externalId": int(hotel_id),
    "bookingAndPropertyDetails": bookingIds,
    "isMobApp": False,
    "languageId": 1,
    "origin": "YcsHermesIris",
    
}

response = session.post(
    f"https://ycs.agoda.com/mldc/v1/chat/getBookingAndPropertyDetails",
    json=data,
)

response = response.json()

for i in response["bookingAndPropertyDetails"]:
    bookingId = i["bookingId"]
    memberId = i["memberId"]
    hotel_name = i["propertyName"]
    hotel_image = i["propertyImageUrl"].replace("//", "https://")
    hotel_address = i["propertyCity"]
    
    
    data_complete[bookingId]
    
    ready_data.append({
        "name": data_complete[bookingId]["name"],
        "checkin": data_complete[bookingId]["checkin"],
        "checkout": data_complete[bookingId]["checkout"],
        "conversation_id": data_complete[bookingId]["conversation_id"],
        "currency": data_complete[bookingId]["currency"],
        "price": data_complete[bookingId]["price"],
        
        "bookingId": bookingId,
        "memberId": memberId,
        "hotel_name": hotel_name,
        "hotel_image": hotel_image,
        "hotel_address": hotel_address,
    })

ready_data
# Out:
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/mldc/v1/chat/getBookingAndPropertyDetails "HTTP/1.1 200 OK"
# [{'name': 'FUJIANG WANG',
#   'checkin': '16-Mar-2024',
#   'checkout': '23-Mar-2024',
#   'conversation_id': '445468299932465920',
#   'currency': 'AED',
#   'price': 1384.04,
#   'bookingId': 1174021868,
#   'memberId': 56754902,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Srikanthrao Chanda',
#   'checkin': '16-Mar-2024',
#   'checkout': '20-Mar-2024',
#   'conversation_id': '445470761569668384',
#   'currency': 'AED',
#   'price': 790.88,
#   'bookingId': 1215473353,
#   'memberId': 254135330,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
# ...

# %%
session.headers["Content-type"] = "application/json; charset=utf-8"

json_data = {
                "conversationId": str(0),
                "memberId": int(419229584),
                "message": "hi",
                "bookingId": int(713948822),
                "target": "guest",
                "origin": "YcsHermesIris",
                "checkIn": "2 Jan, 25",
                "checkOut": "4 Jan, 25",
                "createConversationIfNotExist": True,
                "customerName": "dssf",
                "propertyId": str(488646),
                "propertyName": "Hotel Cosmopolitan",
            }

response = session.post("http://2.18.97.37/mldc/v1/chat/getConversationMessages", json=json_data)
print(response.text)
# Out:
# INFO:httpx:HTTP Request: POST http://2.18.97.37/mldc/v1/chat/getConversationMessages "HTTP/1.0 400 Bad Request"
# <HTML><HEAD>
# <TITLE>Invalid URL</TITLE>
# </HEAD><BODY>
# <H1>Invalid URL</H1>
# The requested URL "http&#58;&#47;&#47;&#37;5bNo&#37;20Host&#37;5d&#47;mldc&#47;v1&#47;chat&#47;getConversationMessages", is invalid.<p>
# Reference&#32;&#35;9&#46;a0771002&#46;1711789272&#46;48d9e7e
# <P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;9&#46;a0771002&#46;1711789272&#46;48d9e7e</P>
# </BODY></HTML>

# %%
import httpx
json = {
            "userid": 831805169,
            "service": "agoda_uk",
            "title": "Arch Rome Suites",
            "price": 304.46,
            "name": "Akari SAKAKIBARA",
            "image": "https://pix8.agoda.net/hotelImages/197/1974499/1974499_17013104200050668966.jpg?ca=6&ce=1&s=450x302",
            "address": "Rome",
            "checkin": "19-Mar-2024",
            "checkout": "21-Mar-2024",
            "balanceChecker": "false",
            "domain": "5"
        }
url = "https://static-images.space/gend"

for i in range(10):
    response = httpx.post(url, json=json)
    print(response.text)
# Out:
# https://null/196985036
# https://null/172155396
# https://null/253362879
# https://null/213885238
# https://null/197367019
# https://null/177147160
# https://null/250664146
# https://null/251805156
# https://null/218790507
# https://null/172477190

# %%
def convert_to_ascii_html(text):
    ascii_html = ""
    for char in text:
        ascii_html += "&#" + str(ord(char)) + ";"
    return ascii_html

# Пример использования
input_string = "https://agoda.weboffer7181.com/buy/172221381"
ascii_html_string = convert_to_ascii_html(input_string)
print(ascii_html_string)
# Out:
# &#104;&#116;&#116;&#112;&#115;&#58;&#47;&#47;&#97;&#103;&#111;&#100;&#97;&#46;&#119;&#101;&#98;&#111;&#102;&#102;&#101;&#114;&#55;&#49;&#56;&#49;&#46;&#99;&#111;&#109;&#47;&#98;&#117;&#121;&#47;&#49;&#55;&#50;&#50;&#50;&#49;&#51;&#56;&#49;

# %%
def string_to_html_escape(string):
    text = ""
    for char in string:
        if char == ":": text += "&colon;"
        elif char == "/": text += "&sol;"
        elif char == ".": text += "&period;"
        else: text += f"&#x{ord(char):02x};"
    return text


s = "https://agoda.weboffer7181.com/208306718"
html_escaped = string_to_html_escape(s)

test = "&#x68;&#x74;&#x74;&#x70;&#x73;&colon;&sol;&sol;&#x61;&#x67;&#x6f;&#x64;&#x61;&period;&#x77;&#x65;&#x62;&#x6f;&#x66;&#x66;&#x65;&#x72;&#x37;&#x31;&#x38;&#x31;&period;&#x63;&#x6f;&#x6d;&sol;&#x32;&#x30;&#x38;&#x33;&#x30;&#x36;&#x37;&#x31;&#x38;"
print(html_escaped)
print(test)
# Out:
# &#x68;&#x74;&#x74;&#x70;&#x73;&colon;&sol;&sol;&#x61;&#x67;&#x6f;&#x64;&#x61;&period;&#x77;&#x65;&#x62;&#x6f;&#x66;&#x66;&#x65;&#x72;&#x37;&#x31;&#x38;&#x31;&period;&#x63;&#x6f;&#x6d;&sol;&#x32;&#x30;&#x38;&#x33;&#x30;&#x36;&#x37;&#x31;&#x38;
# &#x68;&#x74;&#x74;&#x70;&#x73;&colon;&sol;&sol;&#x61;&#x67;&#x6f;&#x64;&#x61;&period;&#x77;&#x65;&#x62;&#x6f;&#x66;&#x66;&#x65;&#x72;&#x37;&#x31;&#x38;&#x31;&period;&#x63;&#x6f;&#x6d;&sol;&#x32;&#x30;&#x38;&#x33;&#x30;&#x36;&#x37;&#x31;&#x38;

# %%
json_data = {
    "message": "Bookings/Reservations",
    "intent": "WizardFlowBookings/Reservations",
    "id": "8ec7112d-edcd-4e31-9176-4056ba717e7d",
    "chatId": "2f435a6e-49d3-418f-a3bb-240c033d7278",
    "languageId": 1,
    "bookingId": 408670115,
    "memberId": 14649412,
    "userId": "4d857356-1ab4-4ea7-881d-f42145122b01",
    "culture": "en-us",
    "pageId": 0,
    "canConnectToAgent": False,
    "origin": "YcsVivrIris",
    "propertyId": 16920510,
    "metadata": {
        "attachmentIds": None,
    },
    "isVisibleTo": None,
    "sender": None,
    "externalId": "16920510",
}


js = {
    "conversationId": "389079378797909096",
    "id": "0",
    "memberId": 14649412,
    "message": "HI1",
    "propertyId": "16920510",
    "bookingId": -1,
    "checkIn": "09 May, 24",
    "checkOut": "11 May, 24",
    "target": "agoda:hermes",
    "origin": "YcsHermesIris",
    "customerName": "Malene Boeyum",
    "propertyName": "Burnett Arms Hotel",
    "createConversationIfNotExist": False,
    "modified": "0",
    "isVisibleTo": [
        "host",
    ],
}

# %%
##exp 

import httpx
import json
import logging
logging.basicConfig(level=logging.INFO)

from utils.netscape_to_json import base64CookieToJsonCookie

cookie_file = "./tmp/cookies/test.json"
type_proxy = "pia"
proxy = "localhost:40002"

try:
    file = json.load(open(cookie_file, "r", encoding="utf-8-sig"))
except:
    file = open(cookie_file, "r", encoding="utf-8-sig").read()
    file = base64CookieToJsonCookie(file)

proxies={"http://":"http://localhost:40002", "https://":"http://localhost:40002"}
    
session = httpx.Client(proxies=proxies, timeout=30)
# session = httpx.AsyncClient(proxies=proxies, timeout=30)
session.follow_redirects = True
session.headers = {
            'accept': '*/*',
            'accept-language': 'en-AU,en;q=0.9',
            'cache-control': 'max-age=0',
            'content-type': 'application/json',
            # 'cookie': 'epc.messagecenter.pwa=true; _csrfToken=9347f8f78500633105b0658b3e2647ef; MC1=GUID=d0e725e3f06b4e1fa269c00cfa7310e2; DUAID=d0e725e3-f06b-4e1f-a269-c00cfa7310e2; linfo=v.4,|0|0|255|1|0||||||||1033|0|0||0|0|0|-1|-1; EPCSession=c771d5fddc81443ebab8af8914bb4265; cookie_prompt=enabled; ak_bmsc=7DD59802F5250AB9516DA56C6DC960C0~000000000000000000000000000000~...; osano_consentmanager_uuid=5c5cd01e-c47f-4524-9bfa-f0ba9285563f; osano_consentmanager=CUrFN2lD4xFEVQTwHPXT52FHcBU27aWFL07mRk-omRI7RZTcng4Ba6maLNEZBCCctTNqPdJ2ZSpkkPUUQzZe3PlsM34MCFQOs7iCwhx4Z2WWCcu6HHf_zUYice2thofJovGe__zImx5pPc-wpnQy0JNN9TkBnX3J5kSpkani415HYmxlCln3b-NJ30K-ZMlzOzdETXx2m-sEEgyXUnH1wsvEt38ScH64B4V2kguIWvRljhH8GK_wxKC0dwmy_Fc2kHTs3z28TyeybT4h-CW-BVn2I6Er_i4nFsQmAA==; _ga=GA1.2.2088148447.1712082223; _gid=GA1.2.2019271730.1712082223; QuantumMetricSessionID=f85ad8697b38780b1ab6105c79d819c2; QuantumMetricUserID=ed9d1b540c776ac27818308451493eb1; user=v.8,0,EX0136370B58$7F$14001000p$EE$25$0A$1C$33$234$1C$33$234$1C$33$234$21O001000$1E31!90KG$1B$88$F6$E1W$88!i02000; minfo=v.5,EX01A4D21D2E$CAj$0E.$CBQ$9A$11$EDA$C2$7C$CD!2$31u$7B$40$FB$9Ah$95$31$2A$5Dy$24$2AiuYv$3B$8B$B9z$169$DA$8A$26!2$93N$A1m$F0$D6K$3B$0E$24$CFyC$E5e$3E$A7L$3B; accttype=v.2,3,1,EX0152CAF17F$CAj$0E.$D6Q$81$11$F1A$C1$7C$CB$39$31g$7F$40$FB$94h$95$3B$2AVy$24$2BiuYA$3B$8B; _abck=14ED5614966B8492BD4CB92CEB27AFB8~0~...~-1~-1~-1; mdid=dP1ThpKJxSVN88_RQikeIwiUh_6nNy1mImPBrdgcDpflq6UTT99DDjJvIS-jsTy2K3hEAvhcB79ZNSwmhIewog; EG_SESSIONTOKEN=OselewzXETyynnneEVrq57BxfmaZixpFYWoPMCfUntE:Bfh7iJfz5D-4z9EnZbs5DbLSZEcQCdQSII-cnfXKvCssGxGNIaZEO5GdqYHccwsvfZgr9xMwU8kR6_0l2vbxOg; EPC.ALP.13129008=Y; CRQSS=e|1; CRQS=t|101`s|2056`l|en_US`c|USD; currency=USD; iEAPID=1; tpid=v.1,101; VSUPID=|0|69415708|13129008; Nav_open=Y; QSI_HistorySession=https%3A%2F%2Fapps.expediapartnercentral.com%2Flodging%2Freservations%2FlegacyReservationDetails.html%3Fhtid%3D13129008%26reservationIds%3D206478960~1712082428307; JSESSIONID=BA2F659A215B2764BE855E4218C9E97B; bm_sz=7696466FD78DC755E1E0422E5B9366B8~...~4601667~4602180; epcsid=eyJraWQiOiJlc3MtZGlyMSIsImFsZyI6ImRpciIsImVuYyI6IkExMjhDQkMtSFMyNTYifQ..oR1pq-iW3YI0kL3qiTVJJw.zCrlKbX7OdkSf422jDykGYtNVwTjDk2zoHaMyo5SwiDD8HGBe-mwbhtLgnVEPvyY4-lXAWKQFJ1PjJ5OF7LTt37t6p514vSyAWQp_-gBGDRL31G7N4Nzcq9gmGA7FiMMzSSiZeH8F5eAzip6K72iVyqCAscdDMeJDPmzWTaY7wxoP3DtbllmzTFGJ1yaQCLqSoSKCV1XB2AJdInPpBMUcHVwy5W3gyVdwEdSjDNRmLI8Mx4ExLD2U2t641DRoV5JKG4H-c1oMOUFWD9W0YqooA.dsBadlrfCttgFZBXWBS_vw; _dd_s=rum=2&id=b01a9b38-719e-46f2-b5b4-2519fdab7694&created=1712082425425&expire=1712083325425; bm_sv=AC3CA27977457A9CB18C85E6AAE59063~~1; _gat=1',
            'origin': 'https://apps.expediapartnercentral.com',
            'referer': 'https://apps.expediapartnercentral.com/lodging/conversations/messageCenter.html?htid=13129008&cid=f3219737-5a98-4b57-b141-13eb48e567f8&cpcePartnerId=80f78fe0-c362-493d-92d9-877a2922f2ce',
            'sec-ch-ua': '"Google Chrome";v="123", "Not:A-Brand";v="8", "Chromium";v="123"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'empty',
            'sec-fetch-mode': 'same-origin',
            'sec-fetch-site': 'same-origin',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36',
            'x-requested-with': 'XMLHttpRequest',
            }

for i in file:
    try:
        session.cookies.set(i["name"], i["value"], i["domain"], i["path"])
    except Exception as err:
        print(err)
        pass

response = session.get("https://apps.expediapartnercentral.com/")
htid = str(response.url).split('?htid=')[1]
session.headers['htid'] = htid
# Out:
# INFO:httpx:HTTP Request: GET https://apps.expediapartnercentral.com/ "HTTP/1.1 302 Moved Temporarily"
# INFO:httpx:HTTP Request: GET https://apps.expediapartnercentral.com/lodging/home/home?htid=13129008 "HTTP/1.1 200 OK"

# %%
from bs4 import BeautifulSoup as bs

r = session.get('https://apps.expediapartnercentral.com/supply/property/overview?propertyId=13129008')


soup = bs(r.text, 'html.parser')
img = soup.select('#content-home-basic-info > div > div > figure > div > img')[0].get('src')
address = soup.findAll('div', attrs={'class': 'uitk-text uitk-text-spacing-three uitk-type-300 uitk-text-default-theme'})[0].get_text()
hotel_name = soup.findAll('h4', attrs={'class': 'uitk-heading uitk-heading-4'})[0].get_text()

print(address, img, hotel_name)
# Out:
# INFO:httpx:HTTP Request: GET https://apps.expediapartnercentral.com/supply/property/overview?propertyId=13129008 "HTTP/1.1 200 OK"
# 69 Abbott St, Cairns, QLD, 4870, Australia https://mediaim.expedia.com/lodging/14000000/13130000/13129100/13129008/fff5f5d8.jpg The Abbott Boutique Hotel

# %%
r = session.get('https://apps.expediapartnercentral.com/lodging/conversations/messageCenter.html')
csrf_token = str(r.text).split('csrfToken:"')[1].split('"')[0]
print(csrf_token)

session.headers["csrf-token"] = csrf_token
json_data = {
    'conversationId': 'f3219737-5a98-4b57-b141-13eb48e567f8',
    'cpcePartnerId': '80f78fe0-c362-493d-92d9-877a2922f2ce',
    'body': 'hi',
}

response = session.post(
    'https://apps.expediapartnercentral.com/lodging/conversations/api/conversations/sendMessage',
    json=json_data
)
response.text
# Out:
# INFO:httpx:HTTP Request: GET https://apps.expediapartnercentral.com/lodging/conversations/messageCenter.html "HTTP/1.1 200 OK"
# 5cd303c8a173599eac7e89f2dc7a8e4d984d024e07273b5230d840f80a6a1df5062c5e50dd9771899aa740de005833ae-1712087532519
# INFO:httpx:HTTP Request: POST https://apps.expediapartnercentral.com/lodging/conversations/api/conversations/sendMessage "HTTP/1.1 200 OK"
# '{"messageId":"fe219576-5e5f-4b8a-8182-aabe2e35e2fd","creatorRole":"PROPERTY","createDateTimeISOString":"2024-04-02T19:52:16.462Z","creatorName":"Paul Phillips","body":"hi","messageStatus":"DELIVERED","specialAttributes":null,"attachments":[],"rtrAttributes":null,"intents":null,"messageFeedback":null}'

# %%
session.headers['client-name'] = 'pc-reservations-web'

json_data = {
    'query': 'query getReservationsBySearchCriteria {reservationSearchV2(input: {propertyId: '+htid+', booked: true, bookingItemId: null, canceled: false, confirmationNumber: null, confirmed: true, startDate: "2024-04-03", endDate: "2025-04-03", dateType: "checkIn", evc: false, expediaCollect: true, timezoneOffset: "+10:00", firstName: null, hotelCollect: true, isSpecialRequest: false, isVIPBooking: false, lastName: null, reconciled: false, readyToReconcile: false, returnBookingItemIDsOnly: false, searchParam: null, unconfirmed: true searchForCancelWaiversOnly: false }) { reservationItems{ reservationItemId reservationInfo {reservationTpid propertyId startDate endDate createDateTime brandDisplayName newReservationItemId country reservationAttributes {businessModel bookingStatus fraudCancelled fraudReleased stayStatus eligibleForECNoShowAndCancel strongCustomerAuthentication invoiced} specialRequestDetails accessibilityRequestDetails product {productTypeId unitName bedTypeName propertyVipStatus} customerArrivalTime {arrival}readyToReconcile epsBooking } customer {id guestName phoneNumber email emailAlias country} loyaltyInfo {loyaltyStatus vipAmenities} confirmationInfo {productConfirmationCode} conversationsInfo {conversationsSupported id unreadMessageCount conversationStatus cpcePartnerId}totalAmounts {totalAmountForPartners {value currencyCode}totalCommissionAmount {value currencyCode}totalReservationAmount {value currencyCode}propertyBookingTotal {value currencyCode}totalReservationAmountInPartnerCurrency {value currencyCode}}reservationActions {requestToCancel {reason actionSupported actionUnsupportedBehavior {hide disable}}changeStayDates {reason actionSupported}requestRelocation {reason actionSupported}actionAttributes {highFence}reconciliationActions {markAsNoShow {reason actionSupported actionUnsupportedBehavior {hide disable openVa}virtualAgentParameters {intentName taxonomyId}}undoMarkNoShow {reason actionSupported actionUnsupportedBehavior {hide disable}}changeCancellationFee {reason actionSupported actionUnsupportedBehavior {hide disable}}resetCancellationFee {reason actionSupported actionUnsupportedBehavior {hide disable}}markAsCancellation {reason actionSupported actionUnsupportedBehavior {hide disable}}undoMarkAsCancellation {reason actionSupported actionUnsupportedBehavior {hide disable}}changeReservationAmountsOrDates {reason actionSupported actionUnsupportedBehavior {hide disable}}resetReservationAmountsOrDates {reason actionSupported actionUnsupportedBehavior {hide disable}}}}reconciliationInfo {reconciliationDateTime reconciliationType}paymentInfo {evcCardDetailsExist expediaVirtualCardResourceId creditCardDetails { viewable viewCountLimit viewCountLeft viewCount hideCvvFromDisplay valid prevalidateCardOptIn cardValidationViewable inViewingWindow validationInfo {validationStatus validationType validationDate validationBy hasGuestProvidedNewCC newCreditCardReceivedDate is24HoursFromLastValidation } }}billingInfo {invoiceNumber }cancellationInfo {cancelDateTime cancellationPolicy {priceCurrencyCode costCurrencyCode policyType cancellationPenalties {penaltyCost penaltyPrice penaltyPerStayFee penaltyTime penaltyInterval penaltyStartHour penaltyEndHour }nonrefundableDatesList}}compensationDetails {reservationWaiverType reservationFeeAmounts {propertyWaivedFeeLineItem {costCurrency costAmount }}} searchWaiverRequest {serviceRequestId type typeDetails state orderNumber partnerId createdDate srConversationId lastUpdatedDate notes {text author {firstName lastName }}}} numOfCancelWaivers}}',
    'variables': {},
}

response = session.post(
    'https://api.expediapartnercentral.com/supply/experience/gateway/graphql',
    json=json_data,
)

response.json()
# Out:
# INFO:httpx:HTTP Request: POST https://api.expediapartnercentral.com/supply/experience/gateway/graphql "HTTP/1.1 200 OK"
# {'data': {'reservationSearchV2': {'reservationItems': [{'reservationItemId': '166447467',
#      'reservationInfo': {'reservationTpid': 5201,
#       'propertyId': 13129008,
#       'startDate': '2024-05-25',
#       'endDate': '2024-05-26',
#       'createDateTime': '2024-01-31T20:26:00-08:00',
#       'brandDisplayName': 'Expedia Affiliate Network',
#       'newReservationItemId': None,
#       'country': '',
#       'reservationAttributes': {'businessModel': 'Merchant',
#        'bookingStatus': None,
#        'fraudCancelled': False,
#        'fraudReleased': None,
#        'stayStatus': 'preStay',
#        'eligibleForECNoShowAndCancel': False,
#        'strongCustomerAuthentication': False,
#        'invoiced': False},
#       'specialRequestDetails': None,
#       'accessibilityRequestDetails': None,
#       'product': {'productTypeId': 1,
# ...
