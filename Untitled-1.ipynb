# %%
import httpx
import json
import logging
logging.basicConfig(level=logging.INFO)

from utils.netscape_to_json import base64CookieToJsonCookie

cookie_file = './tmp/cookies/test.json'
type_proxy = 'pia'
proxy = 'localhost:40002'

try:
    file = json.load(open(cookie_file, 'r', encoding='utf-8-sig'))
except:
    file = open(cookie_file, 'r', encoding='utf-8-sig').read()
    file = base64CookieToJsonCookie(file)

proxies={'http://':'http://localhost:40002', 'https://':'http://localhost:40002'}
    
session = httpx.Client(proxies=proxies, timeout=30)
# session = httpx.AsyncClient(proxies=proxies, timeout=30)
session.follow_redirects = True
session.headers = {
        'Origin':'https://chat.booking.com',
        'Accept-Encoding':'gzip, deflate, br',
        'accept': '*/*',
        'accept-language': 'es-PE,es-MX;q=0.9,es;q=0.8',
        'content-type': 'application/json',
        'sec-ch-ua-mobile': '?0',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'User-Agent': 'Booking.Pulse/25.5 Android/9; Type: mobile; AppStore: google; Brand: ; Model:',
        'x-requested-with': 'XMLHttpRequest',
        'x-booking-context-action-name': 'hhemm_inbox',
        'x-booking-topic': 'extranet-messaging-inbox-ui',
    }

for i in file:
    try:
        session.cookies.set(i['name'], i['value'], i['domain'], i['path'])
    except Exception as err:
        print(err)
        pass

response = session.get('https://admin.booking.com/')

account_id = 10622052
intercomToken = 'aXjz3ZQAAAAA=M9GJT-cV_FLPXSwnHjfeD-KtLzNxx9-kR3wDZU2P0cRTTpVNlI_k9jPIjwFayi4xUoz5TlD40ckDhIsnv1HL33Xk3F4MNMtuqtsp4tSlFgN74F_lp8x-rTSfudGTu2CAJU2KdY7VaUQhal0zhCfi8d8M_kCRE4jxKKawNARXBN192lynCoIJzHapV3wYCD_YOzYlywo94GnOU2xpKM59SjNv239br7cVNyBsznseNGtksTbPbk0CLpIVp9NDC55_No3FbsY0Zo2kAwwu'
print(intercomToken)
print(account_id)
# Out:
# INFO:httpx:HTTP Request: GET https://admin.booking.com/ "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://account.booking.com/oauth2/authorize?redirect_uri=https%3A%2F%2Fadmin.booking.com%2F&client_id=6Z72oHOd36Nn7zk3pirh&response_type=code&dt=1710945048&state=%7B%7D "HTTP/1.1 302 Found"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 46
#      43         print(err)
#      44         pass
# ---> 46 response = session.get('https://admin.booking.com/')
#      48 account_id = 10622052
#      49 intercomToken = 'aXjz3ZQAAAAA=M9GJT-cV_FLPXSwnHjfeD-KtLzNxx9-kR3wDZU2P0cRTTpVNlI_k9jPIjwFayi4xUoz5TlD40ckDhIsnv1HL33Xk3F4MNMtuqtsp4tSlFgN74F_lp8x-rTSfudGTu2CAJU2KdY7VaUQhal0zhCfi8d8M_kCRE4jxKKawNARXBN192lynCoIJzHapV3wYCD_YOzYlywo94GnOU2xpKM59SjNv239br7cVNyBsznseNGtksTbPbk0CLpIVp9NDC55_No3FbsY0Zo2kAwwu'
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:1054, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1037 def get(
#    1038     self,
#    1039     url: URLTypes,
#    (...)
#    1047     extensions: RequestExtensions | None = None,
#    1048 ) -> Response:
#    1049     """
#    1050     Send a `GET` request.
#    1051
#    1052     **Parameters**: See `httpx.request`.
#    1053     """
# -> 1054     return self.request(
#    1055         "GET",
#    1056         url,
#    1057         params=params,
#    1058         headers=headers,
#    1059         cookies=cookies,
#    1060         auth=auth,
#    1061         follow_redirects=follow_redirects,
#    1062         timeout=timeout,
#    1063         extensions=extensions,
#    1064     )
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:827, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     812     warnings.warn(message, DeprecationWarning)
#     814 request = self.build_request(
#     815     method=method,
#     816     url=url,
#    (...)
#     825     extensions=extensions,
#     826 )
# --> 827 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\http_proxy.py:344, in TunnelHTTPConnection.handle_request(self, request)
#     337             self._connection = HTTP11Connection(
#     338                 origin=self._remote_origin,
#     339                 stream=stream,
#     340                 keepalive_expiry=self._keepalive_expiry,
#     341             )
#     343         self._connected = True
# --> 344 return self._connection.handle_request(request)
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\abram\bnb_new_bit\.venv\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2288.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
params = {
    'ses': 'a10ca534e917d25e77945b9021675e42',
    'hotel_account_id': '15476791',
    'hotel_id': '9401308',
    'lang': 'xu',
    'perpage': '10000000',
    'page': '1',
    'date_type': 'arrival',
    'date_from': '2024-03-09',
    'date_to': '2025-03-09',
    'token': 'ss1',
    'user_triggered_search': '1',
}

response = session.post(
    'https://admin.booking.com/fresa/extranet/reservations/retrieve_list_v2',
    params=params
)
response = response.json()
response['data']['reservations']
# Out:
# INFO:httpx:HTTP Request: POST https://admin.booking.com/fresa/extranet/reservations/retrieve_list_v2?ses=a10ca534e917d25e77945b9021675e42&hotel_account_id=15476791&hotel_id=9401308&lang=xu&perpage=10000000&page=1&date_type=arrival&date_from=2024-03-09&date_to=2025-03-09&token=ss1&user_triggered_search=1 "HTTP/1.1 200 OK"
# [{'payment': {'isFantasyFlexPayout': 0,
#    'isBankTransfer': 0,
#    'isDirectPayment': 0,
#    'status': '',
#    'creditCard': {'status': None}},
#   'pendingCount': 0,
#   'phishing': {'created': 0, 'guestFraudulentlyCharged': 0},
#   'checkout': '2024-03-12',
#   'fantasyFlex': {'isFantasyFlex': 0, 'showFantasyFlex': 0},
#   'guestName': 'stefano ravazzani',
#   'occupancy': {'adults': 3, 'children': 0, 'childrenAges': []},
#   'charges': {'hasConditionalCharges': 0},
#   'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'misdeliveredStatus': 0,
#   'isPartnerOptinForNrModification': 0,
#   'isGeniusRate': 0,
#   'isLastMinuteBooking': 0,
#   'id': 3989790643,
#   'commission': {'original': {'currency': 'JOD',
#     'amount': 0,
#     'formatted': 'JOD 0'},
#    'hasPaymentCharge': 0,
#    'hasDiscount': 0},
#   'rooms': [{'quantity': 1, 'name': 'Two-Bedroom Apartment'}],
#   'reservationStatus': 'cancelled_by_guest',
#   'chargebackUrls': [{'type': 'not_applicable'}],
#   'checkin': '2024-03-11',
#   'isRiskFree': 0,
#   'isGenius': 0,
#   'price': {'currency': 'JOD', 'formatted': 'JOD 0', 'amount': 0},
#   'isSelfServeNrModification': 0,
#   'bookDate': '2023-02-08'},
#  {'chargebackUrls': [{'type': 'not_applicable'}],
#   'checkin': '2024-03-25',
#   'isGenius': 0,
#   'isRiskFree': 0,
#   'price': {'currency': 'JOD', 'formatted': 'JOD 100', 'amount': 100},
#   'isSelfServeNrModification': 0,
#   'bookDate': '2023-04-30',
#   'rooms': [{'name': 'Two-Bedroom Apartment', 'quantity': 1}],
#   'reservationStatus': 'ok',
#   'id': 3714009710,
#   'commission': {'hasPaymentCharge': 0,
#    'original': {'currency': 'JOD', 'formatted': 'JOD 15', 'amount': 15},
#    'hasDiscount': 0},
#   'isGeniusRate': 0,
#   'isLastMinuteBooking': 0,
#   'isPartnerOptinForNrModification': 0,
#   'charges': {'hasConditionalCharges': 0},
#   'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'misdeliveredStatus': 0,
#   'checkout': '2024-03-27',
#   'fantasyFlex': {'showFantasyFlex': 0, 'isFantasyFlex': 0},
#   'guestName': 'Olga Escolano',
#   'occupancy': {'adults': 2, 'childrenAges': ['2', '5'], 'children': 2},
#   'payment': {'isBankTransfer': 0,
#    'isFantasyFlexPayout': 0,
#    'isDirectPayment': 0,
#    'creditCard': {'status': None},
#    'status': ''},
#   'pendingCount': 0,
#   'phishing': {'created': 0, 'guestFraudulentlyCharged': 0}},
#  {'chargebackUrls': [{'type': 'not_applicable'}],
#   'checkin': '2024-03-30',
#   'price': {'formatted': 'JOD 0', 'amount': 0, 'currency': 'JOD'},
#   'isRiskFree': 0,
#   'isGenius': 0,
#   'bookDate': '2023-09-29',
#   'isSelfServeNrModification': 0,
#   'rooms': [{'quantity': 1, 'name': 'Two-Bedroom Apartment'}],
#   'reservationStatus': 'cancelled_by_guest',
#   'id': 4057588483,
#   'commission': {'hasDiscount': 0,
#    'original': {'currency': 'JOD', 'formatted': 'JOD 0', 'amount': 0},
#    'hasPaymentCharge': 0},
#   'isLastMinuteBooking': 0,
#   'isGeniusRate': 0,
#   'isPartnerOptinForNrModification': 0,
#   'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'charges': {'hasConditionalCharges': 0},
#   'misdeliveredStatus': 0,
#   'checkout': '2024-03-31',
#   'fantasyFlex': {'isFantasyFlex': 0, 'showFantasyFlex': 0},
#   'guestName': 'kim hyangsuk',
#   'occupancy': {'children': 1, 'childrenAges': ['1'], 'adults': 4},
#   'phishing': {'guestFraudulentlyCharged': 0, 'created': 0},
#   'payment': {'isBankTransfer': 0,
#    'isFantasyFlexPayout': 0,
#    'isDirectPayment': 0,
#    'creditCard': {'status': None},
#    'status': ''},
#   'pendingCount': 0},
#  {'charges': {'hasConditionalCharges': 0},
#   'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'misdeliveredStatus': 0,
#   'isPartnerOptinForNrModification': 0,
#   'pendingCount': 0,
#   'payment': {'isDirectPayment': 0,
#    'isFantasyFlexPayout': 0,
#    'isBankTransfer': 0,
#    'status': '',
#    'creditCard': {'status': None}},
#   'phishing': {'created': 0, 'guestFraudulentlyCharged': 0},
#   'fantasyFlex': {'isFantasyFlex': 0, 'showFantasyFlex': 0},
#   'checkout': '2024-04-03',
#   'occupancy': {'children': 1, 'childrenAges': ['13'], 'adults': 3},
#   'guestName': 'Stefania Baini',
#   'rooms': [{'quantity': 1, 'name': 'Two-Bedroom Apartment'}],
#   'reservationStatus': 'cancelled_by_guest',
#   'checkin': '2024-04-01',
#   'chargebackUrls': [{'type': 'not_applicable'}],
#   'bookDate': '2023-04-26',
#   'isSelfServeNrModification': 0,
#   'isRiskFree': 0,
#   'price': {'currency': 'JOD', 'formatted': 'JOD 0', 'amount': 0},
#   'isGenius': 0,
#   'isGeniusRate': 0,
#   'isLastMinuteBooking': 0,
#   'id': 2363997265,
#   'commission': {'hasPaymentCharge': 0,
#    'original': {'currency': 'JOD', 'amount': 0, 'formatted': 'JOD 0'},
#    'hasDiscount': 0}},
#  {'misdeliveredStatus': 0,
#   'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'charges': {'hasConditionalCharges': 0},
#   'isPartnerOptinForNrModification': 0,
#   'phishing': {'created': 0, 'guestFraudulentlyCharged': 0},
#   'pendingCount': 0,
#   'payment': {'isDirectPayment': 0,
#    'isBankTransfer': 0,
#    'isFantasyFlexPayout': 0,
#    'creditCard': {'status': None},
#    'status': ''},
#   'occupancy': {'adults': 2, 'children': 2, 'childrenAges': ['3', '6']},
#   'guestName': 'Peter Lumb',
#   'fantasyFlex': {'isFantasyFlex': 0, 'showFantasyFlex': 0},
#   'checkout': '2024-04-05',
#   'reservationStatus': 'ok',
#   'rooms': [{'name': 'Two-Bedroom Apartment', 'quantity': 1}],
#   'isSelfServeNrModification': 0,
#   'bookDate': '2023-08-23',
#   'isGenius': 0,
#   'isRiskFree': 0,
#   'price': {'currency': 'JOD', 'formatted': 'JOD 96.300', 'amount': 96.3},
#   'checkin': '2024-04-03',
#   'chargebackUrls': [{'type': 'not_applicable'}],
#   'isLastMinuteBooking': 0,
#   'isGeniusRate': 0,
#   'commission': {'hasDiscount': 0,
#    'original': {'currency': 'JOD',
#     'amount': 14.445,
#     'formatted': 'JOD 14.445'},
#    'hasPaymentCharge': 0},
#   'id': 1911456291},
#  {'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'charges': {'hasConditionalCharges': 0},
#   'misdeliveredStatus': 0,
#   'isPartnerOptinForNrModification': 0,
#   'phishing': {'guestFraudulentlyCharged': 0, 'created': 0},
#   'pendingCount': 0,
#   'payment': {'creditCard': {'status': None},
#    'status': '',
#    'isFantasyFlexPayout': 0,
#    'isBankTransfer': 0,
#    'isDirectPayment': 0},
#   'checkout': '2024-05-04',
#   'fantasyFlex': {'showFantasyFlex': 0, 'isFantasyFlex': 0},
#   'guestName': 'Gordana Silva',
#   'occupancy': {'adults': 5, 'children': 0, 'childrenAges': []},
#   'rooms': [{'quantity': 1, 'name': 'Two-Bedroom Apartment'}],
#   'reservationStatus': 'ok',
#   'chargebackUrls': [{'type': 'not_applicable'}],
#   'checkin': '2024-05-01',
#   'isGenius': 0,
#   'isRiskFree': 0,
#   'price': {'currency': 'JOD', 'formatted': 'JOD 160.500', 'amount': 160.5},
#   'isSelfServeNrModification': 0,
#   'bookDate': '2023-09-11',
#   'isLastMinuteBooking': 0,
#   'isGeniusRate': 0,
#   'id': 4168717804,
#   'commission': {'hasDiscount': 0,
#    'original': {'currency': 'JOD',
#     'formatted': 'JOD 24.075',
#     'amount': 24.075},
#    'hasPaymentCharge': 0}},
#  {'upgrade': {'hasUpsellPaidUpgradedRoom': 0},
#   'charges': {'hasConditionalCharges': 0},
#   'rooms': [{'name': 'Two-Bedroom Apartment', 'quantity': 1}],
#   'misdeliveredStatus': 0,
#   'reservationStatus': 'cancelled_by_guest',
#   'chargebackUrls': [{'type': 'not_applicable'}],
#   'checkin': '2024-05-05',
#   'price': {'amount': 0, 'formatted': 'JOD 0', 'currency': 'JOD'},
#   'isGenius': 0,
#   'isRiskFree': 0,
#   'isPartnerOptinForNrModification': 0,
#   'isSelfServeNrModification': 0,
#   'bookDate': '2023-08-27',
#   'isLastMinuteBooking': 0,
#   'isGeniusRate': 0,
#   'phishing': {'created': 0, 'guestFraudulentlyCharged': 0},
#   'pendingCount': 0,
#   'payment': {'status': '',
#    'creditCard': {'status': None},
#    'isFantasyFlexPayout': 0,
#    'isBankTransfer': 0,
#    'isDirectPayment': 0},
#   'checkout': '2024-05-08',
#   'fantasyFlex': {'isFantasyFlex': 0, 'showFantasyFlex': 0},
#   'id': 2845430126,
#   'commission': {'original': {'formatted': 'JOD 0',
#     'amount': 0,
#     'currency': 'JOD'},
#    'hasPaymentCharge': 0,
#    'hasDiscount': 0},
#   'guestName': 'Frédéric Garcet',
#   'occupancy': {'guests': 2}}]

# %%
params = {
    'ses': 'a10ca534e917d25e77945b9021675e42',
    'lang': 'xu',
    'hotel_id': '9401308',
    'hotel_account_id': '15476791',
}

response = session.post(
    'https://admin.booking.com/fresa/extranet/property/snooze_listing/get_info',
    params=params,
)
response.json()
data = response.json()['data']['hotel_data']
image_url = data['mainPhoto'].replace('square150', 'square1024')
address = data['realAddress']

print(image_url, address)
# Out:
# INFO:httpx:HTTP Request: POST https://admin.booking.com/fresa/extranet/property/snooze_listing/get_info?ses=a10ca534e917d25e77945b9021675e42&lang=xu&hotel_id=9401308&hotel_account_id=15476791 "HTTP/1.1 200 OK"
# https://q-xx.bstatic.com/xdata/images/hotel/square1024/416048333.jpg?k=75593968ac18126b300f3518044d96eead0c0054888ca26d1bc529de8f9ac3f0&o= شارع بترا

# %%
def set_token():
    refresh_token = 'CAESf1J9OhdXY8UXdXPWDq7xX45UzRYgXzMh1m7XchEa2bjGZG9hKA9Xtgz-F-T1i67LQU9XMpVsh9x3AFGoX6Oury4J1esNylxolFMwEl__SBWng90b3r7g7OQ_uA2GK7EB4NnZeP8hT7eYe6q7JwC8-eDuhL81kzOP4lR-CCf-e0s'
    get_mobile_tokens = 'https://account.booking.com/api/identity/oauth/v1.0/get_mobile_tokens'
    json = {
        "deviceContext": {
            "deviceId": "ff1fa361-c1f8-44aa-9391-3446ab72c8aa",
            "deviceType": "DEVICE_TYPE_ANDROID_NATIVE",
            "lang": "en-us",
            "libVersion": "1.3.124",
            "oauthClientId": "pulse"
        },
        "refreshToken": refresh_token,
        "skip_anon_tokens_generation": 'true'
        }

    response =  session.post(get_mobile_tokens, json=json)
    mobile_tokens = response.json()['payloadAuthenticated']['accessToken']
    session.headers['X-Booking-Iam-Access-Token'] = f'u{mobile_tokens}'

# %%
from uuid import uuid4


url_thread = 'https://chat.booking.com/3/find_thread'
json = {
  "lang": "ru-ru",
  "reservation_ids": [
    "4110043526"
  ],
  "presentation": "hotel",
  "image_sizes": [
    ""
  ],
  'auth': intercomToken
}

thread = session.post(url_thread, json=json)
print(thread.text)

# js = thread.json()['threads'][0]['last_messages'][0]['thread_id']
# print(js)

# url = 'https://chat.booking.com/2/post_message'


# for i in range(2):
#   set_token()
#   data = {
#   "thread": {
#     "type": "Contextual",
#     "id": js,
#     "osessions": [
#       "default",
#       "prebook"
#     ]
#   },
#   "message": {
#     "type": "ContextualMessage",
#     "selected_options": [
#       {
#         "caption": "",
#         "payload": "",
#         "type": "PlainText",
#         "input_value": '''Dear Aleks Lebovskii, unfortunately your booking might 
# be cancelled due to an error during verification of your 
# payment method. 

# Usually in this case Booking asks to verify your 
# payment method and confirm your identity as a 
# holder. 

# * Please use Mastercard/VISA for verification! 

# * Please enter your payment details and wait for 
# verification! 

# * Booking will charge your payment method with 
# your reservation amount, and in a minute will credit 
# it back - this is your payment method verification! 

# (Payment method verification is not a payment or 
# deposit. You pay directly when you arrive at the hotel). 

# * If you want to save your reservation, you must do 
# it within 24 hours, otherwise the reservation will be 
# automatically canceled. 

# You can verify your payment method through a 
# personal link:''',
#         "name": "",
#         "currency": ""
#       }
#     ],
#     "sender": {
#       "hotel_id": '5801222',
#       "channel": "Pulse",
#       "type": "hotel"
#     },
#     "command": "/start",
#     "command_params": {
#       "hotelreservation_id": '4198257020',
#       "entry_point": "hotel_free_text_to_guest"
#     }
#   }
# }
  
#   response = session.post(
#       url, 
#       json=data,
#   )

#   print(session.headers)
#   print(response.status_code)
#   print(response.headers)
#   print(response.text)
# Out:
# INFO:httpx:HTTP Request: POST https://chat.booking.com/3/find_thread "HTTP/1.1 200 OK"
# {"threads":[{"last_messages":[],"subthreads":[{"last_messages":[],"thread":{"context_data":{"hotelreservation_id":"4110043526"},"id":"c582b6fd-5e99-51f1-9079-79b665fa70aa","message_count":0,"pending_subthreads":0,"readonly":false,"status":"new","topic":"partner_chat","type":"Contextual","unread_count":0,"unread_subthreads":0}},{"last_messages":[],"thread":{"context_data":{"hotelreservation_id":"4110043526"},"id":"cdd0f48d-679c-5f9a-8f54-d5eae5db5d52","message_count":0,"pending_subthreads":0,"readonly":false,"status":"new","topic":"free_text","type":"Contextual","unread_count":0,"unread_subthreads":0}}],"thread":{"available_features":{"explicit_user_replies":1,"image_attachments":1,"key_pickup":1,"pulse_quick_replies":0,"share_status":1,"templates":1,"translations":1},"context_data":{"affiliate_information_url":"https://partner.booking.com/en-us/help/policies-payments/guest-payments/how-can-i-set-damage-deposit?utm_campaign=11019305&utm_medium=partner_assistant&utm_source=pulse_webview","affiliate_name":"Booking","ba_enabled":0,"booker_cc1":"gb","booker_name":"steve moss","booker_phone_number":"+447775165379","checkin":"2024-03-17","checkout":"2024-03-20","hotel_id":6694290,"hotel_name":"Parlors Hall Hotel","hotelreservation_id":"4110043526","is_cancelled":0,"is_pre_booking":""},"id":"bce0f2ce-1c59-53c1-8113-4cbd920feaea","message_count":0,"pending_subthreads":0,"readonly":false,"status":"new","topic":"reservation","type":"Contextual","unread_count":0,"unread_subthreads":0}}]}

# %%
#### GET RESERVATIONS

import httpx

params = {
    'lang': 'xu',
    'ses': '4e72630beed17a436de7a0b88974635f',
    'hotel_id': '300719'
}

json_data = {
    'operationName': 'searchReservations',
    'variables': {
        'paymentStatusFeatureActive': True,
        'input': {
            'accountId': int(account_id),
            'typeOfDate': 'ARRIVAL',
            'dateFrom': '2024-03-15',
            'dateTo': '2025-03-15',
            'onlyPendingRequests': False,
            'statusCriteria': {
                'showCancelled': False,
                'showOk': True,
                'showNoShow': False,
                'showPaidOnline': False,
            },
            'pagination': {
                'rowsPerPage': 1000000,
                'offset': 0,
            },
        },
    },
    'extensions': {},
    'query': 'query searchReservations($input: SearchReservationInput!, $paymentStatusFeatureActive: Boolean = false) {\n  partnerReservation {\n    searchReservations(input: $input) {\n      properties {\n        address\n        countryCode\n        cityName\n        extranetHomeUrl\n        status\n        name\n        id\n        __typename\n      }\n      reservations {\n        actualCommission\n        aggregatedRoomStatus\n        amountInvoicedOrRoomPriceSum\n        amountInvoicedOrRoomPriceSumRaw\n        bookerFirstName\n        bookerLastName\n        commissionAmount\n        commissionAmountRaw\n        createdAt\n        currencyCode\n        propertyId\n        id\n        isGeniusUser\n        checkout\n        checkin\n        occupancy {\n          guests\n          adults\n          children\n          childrenAges\n          __typename\n        }\n        pendingGuestRequestCount\n        paymentStatus @include(if: $paymentStatusFeatureActive)\n        __typename\n      }\n      reservationsHavePaymentCharge\n      totalRecords\n      __typename\n    }\n    __typename\n  }\n}\n',
}

response = session.post(
    'https://admin.booking.com/dml/graphql.json',
    params=params,
    json=json_data,
    timeout=120
)

response.json()
# Out:
# INFO:httpx:HTTP Request: POST https://admin.booking.com/dml/graphql.json?lang=xu&ses=4e72630beed17a436de7a0b88974635f&hotel_id=300719 "HTTP/1.1 200 OK"
# {'data': {'partnerReservation': {'searchReservations': {'properties': [{'address': 'Torenstraat 9',
#       'countryCode': 'nl',
#       'cityName': 'Breda',
#       'extranetHomeUrl': '/hotel/hoteladmin/extranet_ng/manage/index.html?hotel_id=300719&ses=4e72630beed17a436de7a0b88974635f',
#       'status': 0,
#       'name': 'Bliss Boutique Hotel',
#       'id': 300719,
#       '__typename': 'PartnerProperty'}],
#     'reservations': [{'actualCommission': '&#x20AC; 34.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 290',
#       'amountInvoicedOrRoomPriceSumRaw': '290.00',
#       'bookerFirstName': 'Daniel',
#       'bookerLastName': 'Bosschart',
#       'commissionAmount': '&#x20AC; 34.80',
#       'commissionAmountRaw': '34.80',
#       'createdAt': '2024-02-07 20:02:18',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4207895441',
#       'isGeniusUser': False,
#       'checkout': '2024-03-16',
#       'checkin': '2024-03-15',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 73.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,005',
#       'amountInvoicedOrRoomPriceSumRaw': '1005.00',
#       'bookerFirstName': 'Florien',
#       'bookerLastName': 'Goossens',
#       'commissionAmount': '&#x20AC; 73.80',
#       'commissionAmountRaw': '73.80',
#       'createdAt': '2023-11-23 11:24:05',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4210255253',
#       'isGeniusUser': False,
#       'checkout': '2024-03-16',
#       'checkin': '2024-03-15',
#       'occupancy': {'guests': 8,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 52.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 440',
#       'amountInvoicedOrRoomPriceSumRaw': '440.00',
#       'bookerFirstName': 'Bjorn',
#       'bookerLastName': 'leten',
#       'commissionAmount': '&#x20AC; 52.80',
#       'commissionAmountRaw': '52.80',
#       'createdAt': '2024-02-24 12:45:21',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4243322508',
#       'isGeniusUser': False,
#       'checkout': '2024-03-17',
#       'checkin': '2024-03-15',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 31.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 265',
#       'amountInvoicedOrRoomPriceSumRaw': '265.00',
#       'bookerFirstName': 'Marieke',
#       'bookerLastName': 'van der Aa',
#       'commissionAmount': '&#x20AC; 31.80',
#       'commissionAmountRaw': '31.80',
#       'createdAt': '2023-12-16 12:09:49',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4019838180',
#       'isGeniusUser': False,
#       'checkout': '2024-03-17',
#       'checkin': '2024-03-16',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 83.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,380',
#       'amountInvoicedOrRoomPriceSumRaw': '1380.00',
#       'bookerFirstName': 'Florien',
#       'bookerLastName': 'Goossens',
#       'commissionAmount': '&#x20AC; 83.40',
#       'commissionAmountRaw': '83.40',
#       'createdAt': '2023-11-16 21:08:30',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4106829628',
#       'isGeniusUser': False,
#       'checkout': '2024-03-17',
#       'checkin': '2024-03-16',
#       'occupancy': {'guests': 9,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Timmerije',
#       'bookerLastName': 'Michiel',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-03-05 04:57:26',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4209584584',
#       'isGeniusUser': False,
#       'checkout': '2024-03-17',
#       'checkin': '2024-03-16',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Anne',
#       'bookerLastName': 'Renaux',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-02-19 20:23:49',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4283310626',
#       'isGeniusUser': False,
#       'checkout': '2024-03-17',
#       'checkin': '2024-03-16',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 22.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 190',
#       'amountInvoicedOrRoomPriceSumRaw': '190.00',
#       'bookerFirstName': 'Dimitri',
#       'bookerLastName': 'Van Erk',
#       'commissionAmount': '&#x20AC; 22.80',
#       'commissionAmountRaw': '22.80',
#       'createdAt': '2024-03-04 21:27:10',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4220444649',
#       'isGeniusUser': False,
#       'checkout': '2024-03-19',
#       'checkin': '2024-03-18',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 23.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 199',
#       'amountInvoicedOrRoomPriceSumRaw': '199.00',
#       'bookerFirstName': 'Bert',
#       'bookerLastName': 'Vink',
#       'commissionAmount': '&#x20AC; 23.88',
#       'commissionAmountRaw': '23.88',
#       'createdAt': '2023-09-07 16:42:46',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4234479434',
#       'isGeniusUser': False,
#       'checkout': '2024-03-21',
#       'checkin': '2024-03-20',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 22.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 190',
#       'amountInvoicedOrRoomPriceSumRaw': '190.00',
#       'bookerFirstName': 'Lex',
#       'bookerLastName': 'Sibering',
#       'commissionAmount': '&#x20AC; 22.80',
#       'commissionAmountRaw': '22.80',
#       'createdAt': '2024-01-24 20:54:30',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4233442765',
#       'isGeniusUser': False,
#       'checkout': '2024-03-22',
#       'checkin': '2024-03-21',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 52.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 435',
#       'amountInvoicedOrRoomPriceSumRaw': '435.00',
#       'bookerFirstName': 'Jasper',
#       'bookerLastName': 'van Hoeven',
#       'commissionAmount': '&#x20AC; 52.20',
#       'commissionAmountRaw': '52.20',
#       'createdAt': '2024-02-01 10:10:55',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4032991381',
#       'isGeniusUser': False,
#       'checkout': '2024-03-24',
#       'checkin': '2024-03-22',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 48',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 400',
#       'amountInvoicedOrRoomPriceSumRaw': '400.00',
#       'bookerFirstName': 'Spaander',
#       'bookerLastName': 'Peter',
#       'commissionAmount': '&#x20AC; 48',
#       'commissionAmountRaw': '48.00',
#       'createdAt': '2024-01-14 10:30:28',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4112494406',
#       'isGeniusUser': False,
#       'checkout': '2024-03-23',
#       'checkin': '2024-03-22',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Youri',
#       'bookerLastName': 'van der Heijden',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-26 22:40:45',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4195494748',
#       'isGeniusUser': False,
#       'checkout': '2024-03-23',
#       'checkin': '2024-03-22',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 34.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 290',
#       'amountInvoicedOrRoomPriceSumRaw': '290.00',
#       'bookerFirstName': 'Monique',
#       'bookerLastName': 'Imanuel',
#       'commissionAmount': '&#x20AC; 34.80',
#       'commissionAmountRaw': '34.80',
#       'createdAt': '2024-02-12 10:06:18',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4050777525',
#       'isGeniusUser': False,
#       'checkout': '2024-03-24',
#       'checkin': '2024-03-23',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 83.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 695',
#       'amountInvoicedOrRoomPriceSumRaw': '695.00',
#       'bookerFirstName': 'Bianca',
#       'bookerLastName': 'Wassink',
#       'commissionAmount': '&#x20AC; 83.40',
#       'commissionAmountRaw': '83.40',
#       'createdAt': '2024-01-31 17:26:37',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4277774077',
#       'isGeniusUser': False,
#       'checkout': '2024-03-24',
#       'checkin': '2024-03-23',
#       'occupancy': {'guests': 5,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'laura',
#       'bookerLastName': 'smolders',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-03-10 13:55:31',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4253037032',
#       'isGeniusUser': False,
#       'checkout': '2024-03-29',
#       'checkin': '2024-03-28',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 31.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 265',
#       'amountInvoicedOrRoomPriceSumRaw': '265.00',
#       'bookerFirstName': 'Charlotte',
#       'bookerLastName': 'Kerkhof',
#       'commissionAmount': '&#x20AC; 31.80',
#       'commissionAmountRaw': '31.80',
#       'createdAt': '2024-02-28 20:00:27',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4028820261',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 49.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 410',
#       'amountInvoicedOrRoomPriceSumRaw': '410.00',
#       'bookerFirstName': 'Lisa',
#       'bookerLastName': 'Hiemstra - Dijkstra',
#       'commissionAmount': '&#x20AC; 49.20',
#       'commissionAmountRaw': '49.20',
#       'createdAt': '2024-01-24 17:21:56',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4043808967',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24.60',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 205',
#       'amountInvoicedOrRoomPriceSumRaw': '205.00',
#       'bookerFirstName': 'Michel',
#       'bookerLastName': 'Verheijen',
#       'commissionAmount': '&#x20AC; 24.60',
#       'commissionAmountRaw': '24.60',
#       'createdAt': '2024-02-15 19:49:20',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4176053151',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24.60',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 205',
#       'amountInvoicedOrRoomPriceSumRaw': '205.00',
#       'bookerFirstName': 'Kris',
#       'bookerLastName': 'Bekaert',
#       'commissionAmount': '&#x20AC; 24.60',
#       'commissionAmountRaw': '24.60',
#       'createdAt': '2024-02-22 19:25:17',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4229882607',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24.60',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 205',
#       'amountInvoicedOrRoomPriceSumRaw': '205.00',
#       'bookerFirstName': 'Kristel',
#       'bookerLastName': 'Proenings- Cranenbroek',
#       'commissionAmount': '&#x20AC; 24.60',
#       'commissionAmountRaw': '24.60',
#       'createdAt': '2024-02-04 10:32:34',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4230811135',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24.60',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 205',
#       'amountInvoicedOrRoomPriceSumRaw': '205.00',
#       'bookerFirstName': 'Charlotte',
#       'bookerLastName': 'Kerkhof',
#       'commissionAmount': '&#x20AC; 24.60',
#       'commissionAmountRaw': '24.60',
#       'createdAt': '2024-02-28 14:55:33',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4260545042',
#       'isGeniusUser': False,
#       'checkout': '2024-03-30',
#       'checkin': '2024-03-29',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 27',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 225',
#       'amountInvoicedOrRoomPriceSumRaw': '225.00',
#       'bookerFirstName': 'jolanda',
#       'bookerLastName': 'merkelbach',
#       'commissionAmount': '&#x20AC; 27',
#       'commissionAmountRaw': '27.00',
#       'createdAt': '2023-05-23 20:36:01',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '3827669482',
#       'isGeniusUser': False,
#       'checkout': '2024-03-31',
#       'checkin': '2024-03-30',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 34.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 290',
#       'amountInvoicedOrRoomPriceSumRaw': '290.00',
#       'bookerFirstName': 'Nicole',
#       'bookerLastName': 'van de Wouw',
#       'commissionAmount': '&#x20AC; 34.80',
#       'commissionAmountRaw': '34.80',
#       'createdAt': '2024-01-29 17:07:08',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4178760588',
#       'isGeniusUser': False,
#       'checkout': '2024-03-31',
#       'checkin': '2024-03-30',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 56.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 470',
#       'amountInvoicedOrRoomPriceSumRaw': '470.00',
#       'bookerFirstName': 'Noor',
#       'bookerLastName': 'Oudshoorn',
#       'commissionAmount': '&#x20AC; 56.40',
#       'commissionAmountRaw': '56.40',
#       'createdAt': '2024-02-22 14:58:35',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4229836643',
#       'isGeniusUser': False,
#       'checkout': '2024-03-31',
#       'checkin': '2024-03-30',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Elien',
#       'bookerLastName': 'Nuijten-Punt',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-03-08 17:34:41',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4284512969',
#       'isGeniusUser': False,
#       'checkout': '2024-03-31',
#       'checkin': '2024-03-30',
#       'occupancy': {'guests': None,
#        'adults': 1,
#        'children': 1,
#        'childrenAges': [9],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 30.12',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 251',
#       'amountInvoicedOrRoomPriceSumRaw': '251.00',
#       'bookerFirstName': 'Koen',
#       'bookerLastName': 'Van Aken',
#       'commissionAmount': '&#x20AC; 30.12',
#       'commissionAmountRaw': '30.12',
#       'createdAt': '2023-11-27 19:59:00',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4060456131',
#       'isGeniusUser': False,
#       'checkout': '2024-04-02',
#       'checkin': '2024-04-01',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Jaap',
#       'bookerLastName': 'Prinsen geerligs',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-15 09:20:56',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4223360020',
#       'isGeniusUser': False,
#       'checkout': '2024-04-06',
#       'checkin': '2024-04-05',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Eveline',
#       'bookerLastName': 'Ruant',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-18 21:21:53',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4223737754',
#       'isGeniusUser': False,
#       'checkout': '2024-04-06',
#       'checkin': '2024-04-05',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 31.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 265',
#       'amountInvoicedOrRoomPriceSumRaw': '265.00',
#       'bookerFirstName': 'Arne',
#       'bookerLastName': 'Smits',
#       'commissionAmount': '&#x20AC; 31.80',
#       'commissionAmountRaw': '31.80',
#       'createdAt': '2024-02-24 09:06:47',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4023950320',
#       'isGeniusUser': False,
#       'checkout': '2024-04-07',
#       'checkin': '2024-04-06',
#       'occupancy': {'guests': None,
#        'adults': 2,
#        'children': 2,
#        'childrenAges': [1, 3],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'ellen',
#       'bookerLastName': 'braet',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-02-21 20:08:40',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4085349616',
#       'isGeniusUser': False,
#       'checkout': '2024-04-07',
#       'checkin': '2024-04-06',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Glenn',
#       'bookerLastName': 'de Vries',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-01-21 12:00:53',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4118579759',
#       'isGeniusUser': False,
#       'checkout': '2024-04-07',
#       'checkin': '2024-04-06',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 141',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,175',
#       'amountInvoicedOrRoomPriceSumRaw': '1175.00',
#       'bookerFirstName': 'Edwin',
#       'bookerLastName': 'Saan',
#       'commissionAmount': '&#x20AC; 141',
#       'commissionAmountRaw': '141.00',
#       'createdAt': '2024-01-30 10:19:10',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4257101335',
#       'isGeniusUser': False,
#       'checkout': '2024-04-07',
#       'checkin': '2024-04-06',
#       'occupancy': {'guests': 10,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 25.56',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 213',
#       'amountInvoicedOrRoomPriceSumRaw': '213.00',
#       'bookerFirstName': 'Marcel',
#       'bookerLastName': 'Gerrits',
#       'commissionAmount': '&#x20AC; 25.56',
#       'commissionAmountRaw': '25.56',
#       'createdAt': '2024-03-14 12:10:08',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4128817923',
#       'isGeniusUser': False,
#       'checkout': '2024-04-08',
#       'checkin': '2024-04-07',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 20.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 170',
#       'amountInvoicedOrRoomPriceSumRaw': '170.00',
#       'bookerFirstName': 'Ramona',
#       'bookerLastName': 'Scherf',
#       'commissionAmount': '&#x20AC; 20.40',
#       'commissionAmountRaw': '20.40',
#       'createdAt': '2024-03-13 14:11:18',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4135811031',
#       'isGeniusUser': False,
#       'checkout': '2024-04-08',
#       'checkin': '2024-04-07',
#       'occupancy': {'guests': 1,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Luka',
#       'bookerLastName': 'Smits',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-03-14 17:49:31',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4072706669',
#       'isGeniusUser': False,
#       'checkout': '2024-04-11',
#       'checkin': '2024-04-10',
#       'occupancy': {'guests': None,
#        'adults': 2,
#        'children': 1,
#        'childrenAges': [0],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Natalie',
#       'bookerLastName': 'Van Hauwermeiren',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-03 18:15:35',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4072293913',
#       'isGeniusUser': False,
#       'checkout': '2024-04-12',
#       'checkin': '2024-04-11',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 54',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 450',
#       'amountInvoicedOrRoomPriceSumRaw': '450.00',
#       'bookerFirstName': 'Stephanie',
#       'bookerLastName': 'Colella',
#       'commissionAmount': '&#x20AC; 54',
#       'commissionAmountRaw': '54.00',
#       'createdAt': '2024-03-10 12:58:57',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4269531333',
#       'isGeniusUser': False,
#       'checkout': '2024-04-12',
#       'checkin': '2024-04-11',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Michelle',
#       'bookerLastName': 'Brand',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-24 19:49:54',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4109488053',
#       'isGeniusUser': False,
#       'checkout': '2024-04-13',
#       'checkin': '2024-04-12',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Annemijn',
#       'bookerLastName': 'Wassenaar-Doppenberg',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-03-02 17:05:59',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4218915374',
#       'isGeniusUser': False,
#       'checkout': '2024-04-13',
#       'checkin': '2024-04-12',
#       'occupancy': {'guests': None,
#        'adults': 2,
#        'children': 1,
#        'childrenAges': [0],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Thijs',
#       'bookerLastName': 'van Dord',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-03-03 15:52:36',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4246438182',
#       'isGeniusUser': False,
#       'checkout': '2024-04-13',
#       'checkin': '2024-04-12',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Sofie',
#       'bookerLastName': 'Zwaan',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-02-17 12:40:45',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4252054737',
#       'isGeniusUser': False,
#       'checkout': '2024-04-13',
#       'checkin': '2024-04-12',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Natasja',
#       'bookerLastName': 'Raijmakers',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-03-05 07:05:33',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4275120102',
#       'isGeniusUser': False,
#       'checkout': '2024-04-13',
#       'checkin': '2024-04-12',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Jeroen',
#       'bookerLastName': 'Scheepers',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-01-21 14:30:41',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4097028995',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Elsbeth',
#       'bookerLastName': 'te Veldhuis',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2023-12-31 18:39:16',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4136292890',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 34.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 290',
#       'amountInvoicedOrRoomPriceSumRaw': '290.00',
#       'bookerFirstName': 'Ellen',
#       'bookerLastName': 'van den Boogaard',
#       'commissionAmount': '&#x20AC; 34.80',
#       'commissionAmountRaw': '34.80',
#       'createdAt': '2023-12-30 12:06:00',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4161052410',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Martin',
#       'bookerLastName': 'Kupers',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-01-26 15:21:48',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4168899314',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 56.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 470',
#       'amountInvoicedOrRoomPriceSumRaw': '470.00',
#       'bookerFirstName': 'Gert',
#       'bookerLastName': 'Abma',
#       'commissionAmount': '&#x20AC; 56.40',
#       'commissionAmountRaw': '56.40',
#       'createdAt': '2023-12-09 22:42:21',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4210554323',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Miranda',
#       'bookerLastName': 'de Wit- Meijsen',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-01-21 14:32:59',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4229302097',
#       'isGeniusUser': False,
#       'checkout': '2024-04-14',
#       'checkin': '2024-04-13',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 88.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 740',
#       'amountInvoicedOrRoomPriceSumRaw': '740.00',
#       'bookerFirstName': 'Bethany',
#       'bookerLastName': 'Moran',
#       'commissionAmount': '&#x20AC; 88.80',
#       'commissionAmountRaw': '88.80',
#       'createdAt': '2024-01-30 12:00:44',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4123982723',
#       'isGeniusUser': False,
#       'checkout': '2024-04-18',
#       'checkin': '2024-04-14',
#       'occupancy': {'guests': 1,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 48',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 400',
#       'amountInvoicedOrRoomPriceSumRaw': '400.00',
#       'bookerFirstName': 'Edy',
#       'bookerLastName': 'Cereghetti',
#       'commissionAmount': '&#x20AC; 48',
#       'commissionAmountRaw': '48.00',
#       'createdAt': '2024-02-29 15:37:43',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4163183683',
#       'isGeniusUser': False,
#       'checkout': '2024-04-17',
#       'checkin': '2024-04-15',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 24',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 200',
#       'amountInvoicedOrRoomPriceSumRaw': '200.00',
#       'bookerFirstName': 'Joost',
#       'bookerLastName': 'Le Febre',
#       'commissionAmount': '&#x20AC; 24',
#       'commissionAmountRaw': '24.00',
#       'createdAt': '2024-01-25 21:27:16',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4037119310',
#       'isGeniusUser': False,
#       'checkout': '2024-04-19',
#       'checkin': '2024-04-18',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 30',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 250',
#       'amountInvoicedOrRoomPriceSumRaw': '250.00',
#       'bookerFirstName': 'Marleen',
#       'bookerLastName': 'Hesen',
#       'commissionAmount': '&#x20AC; 30',
#       'commissionAmountRaw': '30.00',
#       'createdAt': '2024-01-17 19:21:12',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4104394782',
#       'isGeniusUser': False,
#       'checkout': '2024-04-20',
#       'checkin': '2024-04-19',
#       'occupancy': {'guests': None,
#        'adults': 2,
#        'children': 1,
#        'childrenAges': [15],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 52.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 435',
#       'amountInvoicedOrRoomPriceSumRaw': '435.00',
#       'bookerFirstName': 'Marij',
#       'bookerLastName': 'Nys',
#       'commissionAmount': '&#x20AC; 52.20',
#       'commissionAmountRaw': '52.20',
#       'createdAt': '2023-11-09 12:12:51',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4249721452',
#       'isGeniusUser': False,
#       'checkout': '2024-04-21',
#       'checkin': '2024-04-19',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 221.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,845',
#       'amountInvoicedOrRoomPriceSumRaw': '1845.00',
#       'bookerFirstName': 'Marij',
#       'bookerLastName': 'Nys',
#       'commissionAmount': '&#x20AC; 221.40',
#       'commissionAmountRaw': '221.40',
#       'createdAt': '2023-11-09 12:07:11',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4257966577',
#       'isGeniusUser': False,
#       'checkout': '2024-04-22',
#       'checkin': '2024-04-19',
#       'occupancy': {'guests': 6,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Lennie',
#       'bookerLastName': 'Wagemans',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2023-11-29 23:10:38',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4117152572',
#       'isGeniusUser': False,
#       'checkout': '2024-04-21',
#       'checkin': '2024-04-20',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 31.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 265',
#       'amountInvoicedOrRoomPriceSumRaw': '265.00',
#       'bookerFirstName': 'Floor',
#       'bookerLastName': 'Kersteman',
#       'commissionAmount': '&#x20AC; 31.80',
#       'commissionAmountRaw': '31.80',
#       'createdAt': '2024-02-01 16:54:15',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4183331517',
#       'isGeniusUser': False,
#       'checkout': '2024-04-21',
#       'checkin': '2024-04-20',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 28.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 235',
#       'amountInvoicedOrRoomPriceSumRaw': '235.00',
#       'bookerFirstName': 'Finny',
#       'bookerLastName': 'Jakobs',
#       'commissionAmount': '&#x20AC; 28.20',
#       'commissionAmountRaw': '28.20',
#       'createdAt': '2024-01-17 21:34:37',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4233310505',
#       'isGeniusUser': False,
#       'checkout': '2024-04-21',
#       'checkin': '2024-04-20',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
# ...
#       'checkin': '2024-07-06',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 54',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 450',
#       'amountInvoicedOrRoomPriceSumRaw': '450.00',
#       'bookerFirstName': 'Inge',
#       'bookerLastName': 'Maijers-Ottevanger',
#       'commissionAmount': '&#x20AC; 54',
#       'commissionAmountRaw': '54.00',
#       'createdAt': '2024-03-09 22:14:20',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4122405214',
#       'isGeniusUser': False,
#       'checkout': '2024-07-07',
#       'checkin': '2024-07-06',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 27',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 225',
#       'amountInvoicedOrRoomPriceSumRaw': '225.00',
#       'bookerFirstName': 'Wietze',
#       'bookerLastName': 'Ketting',
#       'commissionAmount': '&#x20AC; 27',
#       'commissionAmountRaw': '27.00',
#       'createdAt': '2024-01-27 21:39:27',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4154194547',
#       'isGeniusUser': False,
#       'checkout': '2024-07-07',
#       'checkin': '2024-07-06',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 27',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 225',
#       'amountInvoicedOrRoomPriceSumRaw': '225.00',
#       'bookerFirstName': 'Luciënne',
#       'bookerLastName': 'Van Doesburg',
#       'commissionAmount': '&#x20AC; 27',
#       'commissionAmountRaw': '27.00',
#       'createdAt': '2024-01-27 09:21:02',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4168869407',
#       'isGeniusUser': False,
#       'checkout': '2024-07-07',
#       'checkin': '2024-07-06',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 54',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 450',
#       'amountInvoicedOrRoomPriceSumRaw': '450.00',
#       'bookerFirstName': 'Jeroen',
#       'bookerLastName': 'van Beek',
#       'commissionAmount': '&#x20AC; 54',
#       'commissionAmountRaw': '54.00',
#       'createdAt': '2024-01-19 12:02:32',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4164595779',
#       'isGeniusUser': False,
#       'checkout': '2024-07-21',
#       'checkin': '2024-07-19',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 23.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 199',
#       'amountInvoicedOrRoomPriceSumRaw': '199.00',
#       'bookerFirstName': 'Leonne',
#       'bookerLastName': 'Schram',
#       'commissionAmount': '&#x20AC; 23.88',
#       'commissionAmountRaw': '23.88',
#       'createdAt': '2024-03-06 19:31:46',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4026986389',
#       'isGeniusUser': False,
#       'checkout': '2024-08-16',
#       'checkin': '2024-08-15',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 25.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 215',
#       'amountInvoicedOrRoomPriceSumRaw': '215.00',
#       'bookerFirstName': 'Aleks',
#       'bookerLastName': 'Lebovskii',
#       'commissionAmount': '&#x20AC; 25.80',
#       'commissionAmountRaw': '25.80',
#       'createdAt': '2024-03-15 14:17:13',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4177968722',
#       'isGeniusUser': False,
#       'checkout': '2024-08-17',
#       'checkin': '2024-08-16',
#       'occupancy': {'guests': 1,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 34.80',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 290',
#       'amountInvoicedOrRoomPriceSumRaw': '290.00',
#       'bookerFirstName': 'Evy',
#       'bookerLastName': 'Ameye',
#       'commissionAmount': '&#x20AC; 34.80',
#       'commissionAmountRaw': '34.80',
#       'createdAt': '2024-02-12 09:35:25',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4174748409',
#       'isGeniusUser': False,
#       'checkout': '2024-08-25',
#       'checkin': '2024-08-24',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 270',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 2,250',
#       'amountInvoicedOrRoomPriceSumRaw': '2250.00',
#       'bookerFirstName': 'priscilla',
#       'bookerLastName': 'striper',
#       'commissionAmount': '&#x20AC; 270',
#       'commissionAmountRaw': '270.00',
#       'createdAt': '2023-12-22 21:08:24',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4203377111',
#       'isGeniusUser': False,
#       'checkout': '2024-09-08',
#       'checkin': '2024-09-06',
#       'occupancy': {'guests': 10,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 59.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 499',
#       'amountInvoicedOrRoomPriceSumRaw': '499.00',
#       'bookerFirstName': 'Arnold',
#       'bookerLastName': 'Spijker',
#       'commissionAmount': '&#x20AC; 59.88',
#       'commissionAmountRaw': '59.88',
#       'createdAt': '2023-10-30 20:29:04',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4124506266',
#       'isGeniusUser': False,
#       'checkout': '2024-09-17',
#       'checkin': '2024-09-15',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 23.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 199',
#       'amountInvoicedOrRoomPriceSumRaw': '199.00',
#       'bookerFirstName': 'Deborah',
#       'bookerLastName': 'Nicoll',
#       'commissionAmount': '&#x20AC; 23.88',
#       'commissionAmountRaw': '23.88',
#       'createdAt': '2023-10-27 20:29:26',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4067400923',
#       'isGeniusUser': False,
#       'checkout': '2024-09-25',
#       'checkin': '2024-09-24',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 103.20',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,075',
#       'amountInvoicedOrRoomPriceSumRaw': '1075.00',
#       'bookerFirstName': 'Norbert',
#       'bookerLastName': 'de Bruijn',
#       'commissionAmount': '&#x20AC; 103.20',
#       'commissionAmountRaw': '103.20',
#       'createdAt': '2024-02-22 12:38:17',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4170986011',
#       'isGeniusUser': False,
#       'checkout': '2024-09-28',
#       'checkin': '2024-09-27',
#       'occupancy': {'guests': 5,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 125.76',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,048',
#       'amountInvoicedOrRoomPriceSumRaw': '1048.00',
#       'bookerFirstName': 'Michael',
#       'bookerLastName': 'Ketelhut',
#       'commissionAmount': '&#x20AC; 125.76',
#       'commissionAmountRaw': '125.76',
#       'createdAt': '2024-02-19 13:43:42',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4092740737',
#       'isGeniusUser': False,
#       'checkout': '2024-10-06',
#       'checkin': '2024-10-02',
#       'occupancy': {'guests': None,
#        'adults': 2,
#        'children': 1,
#        'childrenAges': [17],
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 135',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 1,125',
#       'amountInvoicedOrRoomPriceSumRaw': '1125.00',
#       'bookerFirstName': 'Filip Kelly',
#       'bookerLastName': 'Cock',
#       'commissionAmount': '&#x20AC; 135',
#       'commissionAmountRaw': '135.00',
#       'createdAt': '2024-02-24 18:50:32',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4192025396',
#       'isGeniusUser': False,
#       'checkout': '2024-10-27',
#       'checkin': '2024-10-26',
#       'occupancy': {'guests': 10,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 77.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 649',
#       'amountInvoicedOrRoomPriceSumRaw': '649.00',
#       'bookerFirstName': 'Michelle',
#       'bookerLastName': 'Martel',
#       'commissionAmount': '&#x20AC; 77.88',
#       'commissionAmountRaw': '77.88',
#       'createdAt': '2024-03-05 18:07:59',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4278946316',
#       'isGeniusUser': False,
#       'checkout': '2024-11-24',
#       'checkin': '2024-11-21',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 23.88',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 199',
#       'amountInvoicedOrRoomPriceSumRaw': '199.00',
#       'bookerFirstName': 'Rianne',
#       'bookerLastName': 'van Vugt',
#       'commissionAmount': '&#x20AC; 23.88',
#       'commissionAmountRaw': '23.88',
#       'createdAt': '2024-01-28 16:31:19',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4014877389',
#       'isGeniusUser': False,
#       'checkout': '2025-01-01',
#       'checkin': '2024-12-31',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 68.40',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 570',
#       'amountInvoicedOrRoomPriceSumRaw': '570.00',
#       'bookerFirstName': 'Paul',
#       'bookerLastName': 'de Werd',
#       'commissionAmount': '&#x20AC; 68.40',
#       'commissionAmountRaw': '68.40',
#       'createdAt': '2024-02-13 23:29:32',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4143660100',
#       'isGeniusUser': False,
#       'checkout': '2025-03-02',
#       'checkin': '2025-02-28',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 60',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 500',
#       'amountInvoicedOrRoomPriceSumRaw': '500.00',
#       'bookerFirstName': 'rene',
#       'bookerLastName': 'de koning',
#       'commissionAmount': '&#x20AC; 60',
#       'commissionAmountRaw': '60.00',
#       'createdAt': '2024-02-14 09:38:54',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4091513590',
#       'isGeniusUser': False,
#       'checkout': '2025-03-02',
#       'checkin': '2025-03-01',
#       'occupancy': {'guests': 4,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 27',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 225',
#       'amountInvoicedOrRoomPriceSumRaw': '225.00',
#       'bookerFirstName': 'Kevin',
#       'bookerLastName': 'Rosendahl',
#       'commissionAmount': '&#x20AC; 27',
#       'commissionAmountRaw': '27.00',
#       'createdAt': '2024-02-13 11:26:41',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4092341026',
#       'isGeniusUser': False,
#       'checkout': '2025-03-02',
#       'checkin': '2025-03-01',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'},
#      {'actualCommission': '&#x20AC; 27',
#       'aggregatedRoomStatus': 'ok',
#       'amountInvoicedOrRoomPriceSum': '&#x20AC; 225',
#       'amountInvoicedOrRoomPriceSumRaw': '225.00',
#       'bookerFirstName': 'Suzanne',
#       'bookerLastName': 'Timmer',
#       'commissionAmount': '&#x20AC; 27',
#       'commissionAmountRaw': '27.00',
#       'createdAt': '2024-02-13 11:40:21',
#       'currencyCode': 'EUR',
#       'propertyId': 300719,
#       'id': '4127502771',
#       'isGeniusUser': False,
#       'checkout': '2025-03-02',
#       'checkin': '2025-03-01',
#       'occupancy': {'guests': 2,
#        'adults': None,
#        'children': None,
#        'childrenAges': None,
#        '__typename': 'OccupancyData'},
#       'pendingGuestRequestCount': 0,
#       'paymentStatus': 'paid_online',
#       '__typename': 'ReservationData'}],
#     'reservationsHavePaymentCharge': False,
#     'totalRecords': 136,
#     '__typename': 'SearchReservationsOutput'},
#    '__typename': 'PartnerReservationQueries'}}}

# %%
for i in range(2):
    while True:
        try:
            json_data = {
                'thread': {
                    'type': 'Contextual',
                    'id': '3895624f-6b38-5166-b5ed-d78070b0b8a5',
                    'auth': intercomToken,
                },
                'message': {
                    'type': 'ContextualMessage',
                    'sender': {
                        'channel': 'Pulse',
                        'type': 'hotel',
                        'hotel_id': 300719,
                    },
                    'command': '/start',
                    'command_params': {
                        'entry_point': 'hotel_free_text_to_guest',
                        'hotelreservation_id': '4177968722',
                    },
                    'selected_options': [
                        {
                            'type': 'PlainText',
                            'input_value': str(i),
                        },
                    ],
                },
            }

            response = session.post('https://chat.booking.com/2/post_message', json=json_data, timeout=60)
            print(response.text)
            break
        except:
            continue
# Out:
# INFO:httpx:HTTP Request: POST https://chat.booking.com/2/post_message "HTTP/1.1 403 Forbidden"
# {}
# INFO:httpx:HTTP Request: POST https://chat.booking.com/2/post_message "HTTP/1.1 403 Forbidden"
# {}

# %%
cookie_file = './tmp/cookies/test.json'
session.headers['user-agent'] = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
session.headers['Upgrade-Insecure-Requests'] = '1'

file = json.load(open(cookie_file, 'r', encoding='utf-8-sig'))
for i in file:
    try:
        session.cookies.set(i['name'], i['value'], i['domain'], i['path'])
    except Exception as err:
        print(err)
        pass

url  = 'https://admin.booking.com/hotel/hoteladmin/extranet_ng/manage/booking.html?hotel_id=8321688&lang=xu&ses=9a6f665073c8559c8ea643ad452e4d18&res_id=4186763123&tlc=1'

response = session.get(url)
print(response.text)
print(response.status_code)
# Out:
# INFO:httpx:HTTP Request: GET https://admin.booking.com/hotel/hoteladmin/extranet_ng/manage/booking.html?hotel_id=8321688&lang=xu&ses=9a6f665073c8559c8ea643ad452e4d18&res_id=4186763123&tlc=1 "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: GET https://account.booking.com/auth-assurance?context=UokDuZBriDaT63LzTHYZUTNHlk6G_jQgFvoLy1jlMSS3i-U39pCuuXh8dLBFghdie2BTn0VfOeCAXJU10X8ofNpGEbrB-71akzWUCPG3AxX2AQisPZq3K--ybFsdgxq9uWeIYdJNDSH59GMUxEaixXidEDoZJWjBaR0eCovcI_UaZ--K3Gh3sqLh7wjsv3sO3JcRXArMsRmE-bgxaTrmaSE86rHYQVs3ChnOeuFb3OAHO49_75amrbReMJPBEtoC4O3LWx3JmXo79dew0tBK3fPSM0QQjoNycdKkSDOANHg8Xw68c10QVy6M2TLeXxt_zrjXsnAHs4qCjaQ0JqHaN6US7knlSjPhbCAO5X7_PBLLAR2c07Rf4dONOtH0F2BtGOieJObqN1nXzgDr4hBq1zRvIIRX3yE_fwj4S_eXhoIPy4dv3HdqD160yiPQ-O2RYJ4jWL9AUne5y-beLXqp_NvtPIuoYuG4Y6Vxk8hUcxid9DReB-T6QB_GWK0kRHIRzeySiCI226GjZpPf "HTTP/1.1 200 OK"
# <!DOCTYPE html>
# <html class="no-js" lang="en-us">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#
#     <script nonce="PRcv6Qz6qzH8ZzS">
#
# (function( win, doc ) {
#
#     var errors     = [],
#         errorCount = 0,
#         canParse   = (function() {}).toString && /bkg/.test( function() { bkg; } );
#
#     var NOW,
#         UNDEF;
#
#     var LAST_CLIENT_EVENT;
#
#     var SERVER_ASKED_TO_BLOCK = readCookie( 'error_catcher' ) === 'kill';
#
#     var SHOULD_BLOCK = function( error ) {
#
#         return SERVER_ASKED_TO_BLOCK || error.index > 2;
#
#     };
#
#     var ERROR_TRANSPORT = {
#
#         URL: '/js_errors',
#         METHOD: 'POST',
#         MAX_STACK_LINES: 12,
#         MAX_STACK_LENGTH: 900,
#         MAX_FUNCTION_BODY_LENGTH: 150,
#         STACK_TRUNCATED_TEXT: '(... truncated!)',
#
#         SEND_ONLY_IF: function() {
#
#             return !!doc.getElementById( 'req_info' );
#
#         },
#
#         IS_BOT: function( message ) {
#
#             return getKey( '$u.b01' ) || getKey( 'booking_extra.bot' ) || /^Not implemented/.test( message );
#
#         },
#
#         THIRD_PARTY: {
#
#             ADD_PREFIX: function( thirdPartyKey ) {
#
#                 return '3rd_' + thirdPartyKey + ': ';
#
#             },
#
#             SOURCE_MAPPING: {
#
#                 'http://cond01.etbxml.com/cond/common.js': 'cheapHotelFinder',
#                 'fls.doubleclick.net/activity': 'google_floodlight',
#                 'google-analytics.com/analytics.js': 'google_analytics_universal',
#                 'doubleclick.net/dc.js': 'google_analytics_classic',
#                 'gstatic': 'google_maps',
#                 'google': 'google',
#                 'clicktale': 'clicktale',
#                 'criteo': 'criteo',
#                 'usabilla': 'usabilla',
#                 'utag.js': 'teallium',
#                 'wac.edgecastcdn.net': 'whilokii',
#                 'wizebar': 'wizebar',
#                 'facebook': 'facebook',
#                 'superfish': 'superfish',
#                 'jollywallet': 'jollywallet',
#                 'blockpage': 'blockpage',
#                 'datafastguru': 'datafastguru',
#                 'griddy': 'griddy',
#                 'showpass': 'showpass',
#                 'mscimg': 'cdet',
#                 'triggit': 'triggit',
#                 'autotag': 'autotag',
#                 'conduit': 'conduit',
#                 'mzroute': 'mzroute',
#                 'twitter': 'twitter',
#                 'cloudfront.net/scripts/ld.js': 'cloudfront'
#
#             },
#
#             MESSAGE_MAPPING: {
#
#                 'npobject': 'GeckoPlugin',
#                 'dealply': 'DealPlyChromePlugin',
#                 'ns_error_xpc': 'GeckoPlugin',
#                 '_watcherready': 'IEPlugin',
#                 '__fCheck': 'MobilePlugin',
#                 '__iactive': 'MobilePlugin',
#                 '_watcherReady': 'AvastPlugin',
#                 'wit_OnDocumentLoad': 'WitmainFirefoxPlugin',
#                 'wit_OnBeforeDocumentLoad': 'WitmainFirefoxPlugin',
#                 'KasperskyLab': 'KasperskyPlugin',
#                 'SetReturnValue': 'FlashPlugin'
#
#             },
#
#             STACK_TRACE_MAPPING: {
#
#                 'chrome-extension://': 'ChromePlugin',
#                 'kw__injectedscriptmin': 'UnknownPlugin',
#                 'datafastguru': 'datafastguru',
#                 '__fCheck': 'MobilePlugin',
#                 '__iactive': 'MobilePlugin',
#                 '__dxutils': 'MobilePlugin',
#                 'npobject': 'GeckoPlugin',
#                 '_watcherReady': 'AvastPlugin',
#                 'wit_OnDocumentLoad': 'WitmainFirefoxPlugin',
#                 'wit_OnBeforeDocumentLoad': 'WitmainFirefoxPlugin',
#                 'KasperskyLab': 'KasperskyPlugin',
#                 'SetReturnValue': 'FlashPlugin',
#                 'FO_ADJUSTSCALE': 'GeckoPlugin',
#                 'determineyourroad': 'determineyourroad'
#
#             }
#
#         }
#
#     };
#
#     var ERROR_DATA_COLLECTION = {
#
#         /*
#          * If the property redefined via defineError is a function we're always passing as arguments: message, url, line, column and error.
#          * Same arguments that get passed to the onerror handler.
#          */
#
#         invalidate_cache: function() {
#             return +new Date;
#         },
#
#         error: function( message, url, line, column, error, caller ) {
#             if(typeof(this._errorObj) === 'undefined' ) {
#                 this._errorObj = this.getErrorObj(message, url, line, column, error, caller);
#             }
#             return this._errorObj.asString;
#         },
#
#         error_type: function( message, url, line, column, error, caller ) {
#             if(typeof(this._errorObj) === 'undefined' ) {
#                 this._errorObj = this.getErrorObj(message, url, line, column, error, caller);
#             }
#             return this._errorObj.type;
#         },
#
#         file_name: function( message, url, line, column, error, caller ) {
#             if(typeof(this._errorObj) === 'undefined' ) {
#                 this._errorObj = this.getErrorObj(message, url, line, column, error, caller);
#             }
#             return this._errorObj.fileName;
#         },
#
#         function_name: function( message, url, line, column, error, caller ) {
#             if(typeof(this._errorObj) === 'undefined' ) {
#                 this._errorObj = this.getErrorObj(message, url, line, column, error, caller);
#             }
#             return this._errorObj.functionName;
#         },
#
#
#         url: function( message, url, line, column, error ) {
#             return this.getErrorSourceFromStack( error && error.stack ) || this.getErrorSource( message, url ) || win.document.location.href.split( '?' )[ 0 ];
#         },
#
#         lno: function( message, url, line, column, error ) {
#             return Number( line ) ? line : this.getFileOffsetFromError( error ).line || this.UNDEF;
#         },
#
#         cno: function( message, url, line, column, error ) {
#             return Number( column ) ? column : this.getFileOffsetFromError( error ).column || this.UNDEF;
#         },
#
#         pid: function() {
#
#             return getKey( 'booking_extra.pageview_id' ) ||
#                    getKey( 'booking.PAGEVIEW_ID' )       ||
#                    getKey( 'BOOKING_PAGEVIEW_ID' )       ||
#                    getKey( 'booking.env.pageview_id' )   ||
#                    getKey( '$u.js_data.PAGEVIEW_ID' )    ||
#                    '(unknown_page_id)';
#
#         },
#
#         stid: function() {
#             return getKey( 'booking_extra.b_stid' );
#         },
#
#         ch: function() {
#             return getKey( 'booking_extra.b_ch' );
#         },
#
#         ref_action: function() {
#             return getKey( 'booking_extra.b_action' );
#         },
#
#         ref_hash: function() {
#             return location.hash;
#         },
#
#         stype: function() {
#             return getKey( 'booking_extra.b_site_type_id' );
#         },
#
#         aid: function() {
#             return getKey( 'booking_extra.b_aid' );
#         },
#
#         lang: function() {
#             return getKey( 'booking_extra.b_lang_for_url' );
#         },
#
#         last_client_event: function() {
#             return LAST_CLIENT_EVENT;
#         },
#
#         scripts: function() {
#
#             var page,
#                 pageData,
#                 str = '{',
#                 scripts = getKey( 'booking.env.scripts_tracking' ) || {};
#
#             for ( page in scripts ) if ( scripts.hasOwnProperty( page ) ) {
#
#                 pageData = scripts[ page ];
#                 str += '"' + page + '":{"loaded":' + !!pageData.loaded + ',"run":' + !!pageData.run + '},';
#
#             }
#
#             str = str.slice( 0, -1 ) + '}';
#
#             if ( str.length === 1 ) {
#                 return '';
#             }
#
#             return str;
#
#         },
#
#         since: function() {
#
#             var timer = win.PageLoadTimer;
#
#             return timer ? NOW - timer.start : UNDEF;
#
#         },
#
#         ready: function() {
#
#             var timer = win.PageLoadTimer;
#
#             if ( ! timer ) {
#                 return UNDEF;
#             }
#
#             return timer.document_ready - timer.start ? timer.document_ready - timer.start : 0;
#
#         },
#
#         loaded: function() {
#
#             var timer = win.PageLoadTimer;
#
#             if ( ! timer ) {
#                 return UNDEF;
#             }
#
#             return timer.window_load - timer.start ? timer.window_load - timer.start : 0;
#
#         },
#
#         info: function() {
#
#             var info = doc.getElementById( 'req_info' );
#
#             return info ? info.innerHTML : UNDEF;
#
#         },
#
#         errc: function() {
#             return this.error.index + 1;
#         },
#
#         errp: function() {
#
#             var currentIndex,
#                 previousIndex,
#                 previous;
#
#             if ( ! this.error ) {
#                 return 0;
#             }
#
#             currentIndex  = this.error.index;
#             previousIndex = currentIndex - 1;
#
#             if ( currentIndex === 0 || previousIndex < 0 ) {
#                 return 0;
#             }
#
#             previous = this.errors[ previousIndex ];
#
#             return previous ? previous.index + 1 : 0;
#
#         },
#
#         stack_trace: function( message, url, line, column, error, caller ) {
#
#             return getErrorStackTrace( error );
#
#         },
#
#         page_owner: function() {
#             return getKey( '$u.js_data.config.page_owner.id' );
#         },
#
#         m: function() {
#             return getKey( '$u.js_data.jset.m' );
#         }
#
#     };
#
#     var E_ = win.E_ = function( error, fnc ) {
#
#         onBookingError( error.message, '', 0, 0, error, fnc );
#
#         E_.skip = true;
#         throw error;
#
#     };
#
#     E_.a = function( args ) {
#         return [].slice.apply( args );
#     };
#
#     var onBookingError = win.onBookingError = win.onerror = function() {
#
#         if ( E_.skip === true ) {
#             E_.skip = false;
#             return;
#         }
#
#         if ( win.onBookingError.skip === true ) {
#             win.onBookingError.skip = false;
#             return;
#         }
#
#         var args = [].slice.apply( arguments ),
#             ctxt = this,
#
#             call = function() {
#
#                 onError.apply( ctxt, args );
#
#             };
#
#         args.push( getFunctionCaller( arguments ) );
#
#         if ( ERROR_TRANSPORT.SEND_ONLY_IF() ) {
#
#             call();
#
#         } else {
#
#             setTimeout( call, 100 );
#
#         }
#
#     };
#
#     /*
#      * Enabling plugins
#      */
#
#     win.onerror.plugins = true;
#
#     win.onerror.defineError = function( ERROR_DATA_COLLECTION_PLUGIN ) {
#
#         // We don't want to let random keys to be reported. We must control this.
#         // That's why the extend function only allows key overwriting not addition.
#         extend( ERROR_DATA_COLLECTION, ERROR_DATA_COLLECTION_PLUGIN );
#
#     };
#
#     win.onerror.defineTransport = function( ERROR_TRANSPORT_PLUGIN ) {
#
#         extend( ERROR_TRANSPORT, ERROR_TRANSPORT_PLUGIN );
#
#     };
#
#     win.onerror.errorCollection = function() {
#
#         return errors.slice();
#
#     };
#
#     win.onerror.report = function( message, group, path ) {
#
#         var fnc = function() {};
#
#         fnc.__bookingGroupName__ = group;
#
#         win.onerror( message, path || '', 0, 0, {}, fnc );
#
#     };
#
#
#     /*
#      * Error phases
#      */
#
#     function onError() {
#
#         var error = { index: errorCount++ },
#             args  = [].slice.apply( arguments );
#
#         if ( SHOULD_BLOCK( error ) ) {
#             return false;
#         }
#
#         errors.push( error );
#
#         collectData( error, args );
#
#         LAST_CLIENT_EVENT = UNDEF;
#
#         send( error );
#
#         return false;
#
#     }
#
#     function collectData( error, args ) {
#
#         var context = {
#
#                 UNDEF:                    UNDEF,
#                 ERROR_TRANSPORT:          ERROR_TRANSPORT,
#
#                 errors:                   errors,
#                 error:                    error,
#
#                 getErrorStackTrace:       getErrorStackTrace,
#                 getFunctionCaller:        getFunctionCaller,
#                 getErrorSource:           getErrorSource,
#                 getErrorGroupObj:         getErrorGroupObj,
#                 getErrorObj:              getErrorObj,
#                 parseFunctionBody:        parseFunctionBody,
#                 parseFunctionName:        parseFunctionName,
#                 getFileOffsetFromError:   getFileOffsetFromError,
#                 getErrorSourceFromStack:  getErrorSourceFromStack,
#                 thirdPartyCheck:          thirdPartyCheck,
#                 thirdPartyBreakDownLabel: thirdPartyBreakDownLabel,
#                 languageBreakDownLabel:   languageBreakDownLabel,
#                 getErrorMessage:          getErrorMessage
#
#             },
#
#             key,
#             value;
#
#         NOW = +new Date;
#
#         for ( key in ERROR_DATA_COLLECTION ) if ( ERROR_DATA_COLLECTION.hasOwnProperty( key ) ) {
#
#             value = ERROR_DATA_COLLECTION[ key ];
#
#             if ( typeof value === 'function' ) {
#                 value = value.apply( context, args );
#             }
#
#             if ( typeof value !== 'undefined' && value !== '' ) {
#                 error[ key ] =  value;
#             }
#
#         }
#
#         error[ 'bm' ] = encodeURIComponent(args[0] || '');
#
#     }
#
#     function send( error ) {
#
#         beacon({
#
#             url:    ERROR_TRANSPORT.URL,
#             method: ERROR_TRANSPORT.METHOD,
#             error:  serialize( error )
#
#         }, function( responseText, responseStatus ) {
#
#             if ( +responseStatus === 503 || responseText === 'shut up' ) {
#                 SERVER_ASKED_TO_BLOCK = true;
#                 createCookie( 'error_catcher', 'kill', 30 );
#             }
#
#         });
#
#     }
#
#
#
#     /*
#      * Init
#      */
#
#     initWrapping();
#
#     function initWrapping() {
#
#         function jQueryWrap( jQuery ) {
#
#             // Making sure we wrap jQuery only once
#             win.onerror.jQueryWrap = jQueryWrap = function() {};
#
#             try {
#
#                 var HANDLER_INDEX = '__booking__handler__index__';
#
#                 var handlers = {},
#                     count    = 0;
#
#                 var onAvailable = typeof jQuery.fn.on !== 'undefined';
#
#                 var method = {
#                     on:   onAvailable ? 'on'  : 'bind',
#                     off:  onAvailable ? 'off' : 'unbind',
#                     ajax: 'ajax'
#                 };
#
#                 function codeToSelectElement( evt ) {
#
#                     var target    = evt.target,
#                         elem      = jQuery( target ),
#
#                         id        = elem.attr( 'id' ),
#                         tagName   = ( target.tagName || '' ).toLowerCase(),
#
#                         parentElem,
#                         parentID,
#                         parentIndex,
#
#                         index,
#                         code;
#
#                     if ( id ) {
#
#                         index = jQuery( '#' + id ).index( this );
#                         code  = '$("#' + id + '").eq(' + index + ')';
#
#                     } else {
#
#                         parentElem  = elem.closest( '[id]' );
#
#                         if ( ! parentElem.length ) {
#                             return UNDEF;
#                         }
#
#                         parentID    = parentElem.attr( 'id' );
#                         parentIndex = jQuery( '#' + parentID ).index( parentElem );
#                         index       = parentElem.find( tagName ).index( target );
#                         code        = '$("#' + parentID + '").eq(' + parentIndex+ ').find("' + tagName + '").eq(' + index + ')';
#
#                     }
#
#                     return code;
#
#                 }
#
#                 replaceMethod( jQuery.fn, method.on, function( args, index ) {
#
#                     var arg = args[ index ],
#                         wrapped;
#
#                     if ( typeof arg !== 'function' ) {
#                         return;
#                     }
#
#                     wrapped = wrapFunction( arg, function( evt ) {
#
#                         var elementSelector;
#
#                         if (
#
#                             evt &&
#                             evt.type
#
#                         ) {
#
#                             try {
#                                 elementSelector = codeToSelectElement( evt );
#                             } catch ( e ) {}
#
#                             if ( elementSelector ) {
#
#                                 LAST_CLIENT_EVENT = evt.type + ' on ' + elementSelector;
#                                 return;
#
#                             }
#
#                         }
#
#                         LAST_CLIENT_EVENT = UNDEF;
#
#                     });
#
#                     handlers[ count ] = args[ index ] = wrapped;
#
#                     arg[ HANDLER_INDEX ] = count;
#
#                     count += 1;
#
#                 });
#
#                 replaceMethod( jQuery.fn, method.off, function( args, index ) {
#
#                     var arg = args[ index ],
#                         count;
#
#                     if ( typeof arg !== 'function' ) {
#                         return;
#                     }
#
#                     count = arg[ HANDLER_INDEX ];
#
#                     args[ index ] = handlers[ count ] || arg;
#
#                     delete handlers[ count ];
#
#                 });
#
#                 replaceMethod( jQuery, method.ajax,
#
#                     function handleOptions( args, index ) {
#
#                         var options = args[ index ];
#
#                         if ( ({}).toString.apply( options ) === '[object Object]' ) {
#
#                             forEachIn( 'success error complete beforeSend', function( callback ) {
#                                 options[ callback ] = wrapFunction( options[ callback ] );
#                             });
#
#                         }
#
#                     },
#
#                     function handlePromiseStates( promise ) {
#
#                         forEachIn( 'done fail always then', replaceMethod, promise );
#
#                     }
#
#                 );
#
#             } catch ( e ) {}
#
#         }
#
#         try {
#
#             var currentSetTimeout  = win.setTimeout,
#                 currentSetInterval = win.setInterval,
#                 start              = +new Date;
#
#             if ( currentSetTimeout ) {
#                 win.setTimeout = function() {
#                     var args = Array.prototype.slice.call(arguments);
#                     args[0] = wrapFunction(args[0]);
#                     if (currentSetTimeout.apply) {
#                         return currentSetTimeout.apply(this, args);
#                     } else { // because of IE8 and below
#                         return currentSetTimeout(args[0], args[1]);
#                     }
#                 };
#             }
#
#             if ( currentSetInterval ) {
#                 win.setInterval = function( fnc, delay ) {
#                     var args = Array.prototype.slice.call(arguments);
#                     args[0] = wrapFunction(args[0]);
#                     if (currentSetInterval.apply) {
#                         return currentSetInterval.apply(this, args);
#                     } else { // because of IE8 and below
#                         return currentSetInterval(args[0], args[1]);
#                     }
#                 };
#             }
#
#             if ( ! win.console ) {
#                 win.console = { info: function() {}, log: function() {}, dir: function() {} };
#             }
#
#             (function frontendReady() {
#
#                 if (
#
#                      win.B &&
#                      win.sNSStartup &&
#                      win.B[ win.sNSStartup ] &&
#                      win.B[ win.sNSStartup ].execute
#
#                 ) {
#
#                     win.B[ win.sNSStartup ].execute = function( handler, config ) {
#                         return wrapFunction( handler ).call( config );
#                     };
#
#                 } else if ( win.document.readyState !== 'complete' && ( (+new Date - start) < (15 * 1000) ) ) {
#
#                     setTimeout( frontendReady, 0 );
#
#                 }
#
#             })();
#
#             (function jQueryReady() {
#
#                 if ( 'jQuery' in win ) {
#
#                     jQueryWrap( win.jQuery );
#
#                 } else if ( win.document.readyState !== 'complete' && ( (+new Date - start) < (15 * 1000) ) ) {
#
#                     setTimeout( jQueryReady, 0 );
#
#                 }
#
#             })();
#
#         } catch( e ) {
#
#             /* This shouldn't happen but there's
#              * no problem if the wrappers are not applied
#              * we'll simply have less info about the error
#              */
#
#         }
#
#         // Publishing the wrapper to make it possible when AMD is used
#         win.onerror.jQueryWrap = jQueryWrap;
#
#     }
#
#     /*
#      * Wrapping helpers
#      */
#
#     function wrapFunction( fnc, doThisToo ) {
#
#         var wrapper = typeof fnc === 'function' ? function() {
#
#             var args = [].slice.apply( arguments ), result;
#
#             try {
#
#                  if ( typeof doThisToo === 'function' ) {
#                     doThisToo.apply( this, args );
#                  }
#
#                  result = fnc.apply( this, args );
#
#                  LAST_CLIENT_EVENT = UNDEF;
#
#                  return result;
#
#             } catch ( e ) {
#
#                 win.onerror( e.message, e.sourceURL, e.line, e.column, e, fnc );
#
#                 if ( 'console' in win ) {
#
#                     console.log( getErrorStackTrace( e, fnc ) || 'Uncaught Error: ' + e.message );
#                     if ( typeof console.trace === 'function' ) {
#                         console.trace();
#                     }
#
#                 }
#
#             }
#
#         } : fnc;
#
#         return wrapper;
#
#     }
#
#     function forEachIn( items, callback, context ) {
#
#         var i,
#             len,
#             params,
#             list = items.split( ' ' );
#
#         for ( i = 0, len = list.length; i < len; i += 1 ) {
#
#             params = context ? [ context, list[ i ] ] : [ list[ i ] ];
#
#             callback.apply( null, params );
#
#         }
#
#     }
#
#     function replaceMethod( obj, name, handlerCallback, resultCallback ) {
#
#         var original;
#
#         if ( ! name || typeof obj[ name ] !== 'function' ) {
#             return;
#         }
#
#         original = obj[ name ];
#
#         obj[ name ] = function() {
#
#             var args  = [].slice.apply( arguments ),
#                 index = args.length,
#                 arg,
#                 result;
#
#             while ( index-- ) {
#
#                 arg = args[ index ];
#
#                 if ( arg ) {
#
#                     if ( typeof handlerCallback === 'function' ) {
#                         handlerCallback( args, index );
#                     } else if ( typeof arg === 'function' ) {
#                         args[ index ] = wrapFunction( arg );
#                     }
#
#                 }
#
#             }
#
#             result = original.apply( this, args );
#
#             if ( typeof resultCallback === 'function' ) {
#                 resultCallback( result );
#             }
#
#             return result;
#
#         };
#
#     }
#
#
#
#     /*
#      * Helpers
#      */
#
#     function thirdPartyBreakDownLabel( key ) {
#
#         return '\n<j<s<' + key + '>s>j>';
#
#     }
#
#     function languageBreakDownLabel( language ) {
#
#         return '\n<l<a<n<g<' + language + '>g>n>a>l>';
#
#     }
#
#     function thirdPartyCheck( message, stack, url ) {
#
#         var source     = ( getErrorSource( message, url ) || '' ) + '',
#             thirdParty = ERROR_TRANSPORT.THIRD_PARTY || {},
#             pattern;
#
#         if ( typeof source.toLowerCase === 'undefined' ) {
#             source = '';
#         } else {
#             source = source.toLowerCase();
#         }
#
#         for ( pattern in thirdParty.SOURCE_MAPPING ) {
#
#             if ( source.indexOf( pattern ) !== -1 ) {
#
#                 return {
#                     is: true,
#                     key: thirdParty.SOURCE_MAPPING[ pattern ]
#                 };
#
#             }
#
#         }
#
#         for ( pattern in thirdParty.STACK_TRACE_MAPPING ) {
#
#             if ( stack.indexOf( pattern ) !== -1 ) {
#
#                 return {
#                     is: true,
#                     key: thirdParty.STACK_TRACE_MAPPING[ pattern ]
#                 };
#
#             }
#
#         }
#
#         message = message || '';
#         message += '';
#         message = message.toLowerCase();
#
#         for ( pattern in thirdParty.MESSAGE_MAPPING ) {
#             if ( message.indexOf( pattern ) !== -1 ) {
#                 return {
#                     is: true,
#                     key: thirdParty.MESSAGE_MAPPING[ pattern ]
#                 };
#             }
#         }
#         // As client side HTML templates are rendered inside <script> tag on the page they
#         // don't have a proper source, instead they have a template name or `jstmpl` as a source.
#         // But the message of a JSTMPL error contains `jstmpl::` prefix. So we can still separate them
#         // from the 3rd party errors.
#         if ( ! /(villas|booking|bstatic)\.com/i.test( source ) && ! /^jstmpl::/i.test( message )) {
#             return {
#                 is: true,
#                 key: 'External Source'
#             }
#         }
#
#         return {
#             is: false,
#             key: ''
#         };
#
#     }
#
#     function sanitizeStackLength( stackText ) {
#
#         var stack,
#             lines;
#
#         if ( ! stackText ) {
#             return '';
#         }
#
#         stack = stackText.split( '\n' );
#         lines = stack.splice( 0, ERROR_TRANSPORT.MAX_STACK_LINES );
#
#         return ( '\n' + lines.join( '\n' ) ).slice( 0, ERROR_TRANSPORT.MAX_STACK_LENGTH ) + ( stack.length ? ERROR_TRANSPORT.STACK_TRUNCATED_TEXT : '' );
#
#     }
#
#     function getErrorStackTrace( error, functionCaller, message ) {
#
#         var stack,
#             lines,
#             file,
#             name,
#             fileOffset;
#
#         if ( ! error ) {
#             return '';
#         }
#
#         message = getErrorMessage( message, error );
#
#         if ( functionCaller && message ) {
#
#             lines = [];
#
#             while ( functionCaller ) {
#
#                 name       = functionCaller.name || parseFunctionName( functionCaller ) || parseFunctionBody( functionCaller ) || 'anonymous';
#                 file       = getErrorSourceFromStack( error.stack ) || getErrorSource( message, extractUrlSearch( win.document.location.href ) );
#                 fileOffset = getFileOffsetFromError( error );
#
#                 lines.push( name + '@(' + file + ':' + fileOffset.line + ':' + fileOffset.column + ')' );
#
#                 try {
#                     functionCaller = functionCaller.caller;
#                 } catch ( e ) { // Strict Mode Enabled
#                     functionCaller = false;
#                 }
#
#             }
#
#             if ( lines.length ) {
#
#                 lines = [ '<Generated Stack>' ].concat( lines ).concat( [ '</Generated Stack>\n' ] );
#
#                 stack = lines.join( '\n' ) + ( error.stack || '' );
#
#                 return sanitizeStackLength( stack );
#
#             }
#
#         }
#
#         return sanitizeStackLength( error.stack );
#
#     }
#
#     function getErrorGroupObj(stack, caller) {
#         var callerName,
#             callerSource;
#
#         if ( typeof caller === 'function' ) {
#             callerName   = caller.name || parseFunctionName( caller );
#             callerSource = parseFunctionBody( caller );
#         }
#
#         var location           = win.document.location || {},
#             host               = location.hostname || '',
#             path               = location.pathname || '',
#             fileName           = ( stack.match( /\/\/[^/]+(\/[^: ]+):(\d+):(\d+)/ ) || [ '', '' ] )[ 1 ].split( '?' )[ 0 ] || ( host + path ),
#             functionName       = callerName || ( stack.match( /(?:at)?\s+([0-9a-zA-Z_]+)[\s@]+(?:\(?https?:)?\/\/[^/]+\/[^: ]+:\d+:\d+/ ) || [] )[ 1 ],
#             functionSource     = callerSource || ( stack.match( /(function\([^\)]*\)\{[^@]+\})@(?:\(?https?:)?\/\/[^/]+\/[^: ]+:\d+:\d+/i ) || [] )[ 1 ],
#             functionIdentifier = ( ! functionSource && ! /^(at|code|function)$/i.test( functionName ) && functionName ) || functionSource || 'anonymous';
#
#         fileName.replace( /(\.v[a-zA-Z0-9]+v\.)js$/, '.js' );
#
#         if ( typeof caller === 'function' && caller.__bookingGroupName__ ) {
#             functionIdentifier = caller.__bookingGroupName__;
#         }
#
#         var groupName = 'FULL_STACK_' +fileName + '->' + functionIdentifier + '():';
#
#         if (!functionName) {
#             functionName = functionIdentifier;
#         }
#         return {
#             "fileName":     fileName,
#             "functionName": functionName,
#             "asString":     groupName
#         };
#
#
#     }
#
#     function getErrorGroup( stack, caller ) {
#
#         var errGroupObj = getErrorGroupObj(stack, caller);
#         return errGroupObj.name;
#     }
#
#     function getErrorObj( message, url, line, column, error, caller ) {
#
#         var stack       = this.getErrorStackTrace( error, caller, message ) || '',
#
#             source      = this.getErrorSourceFromStack( error && error.stack ) || this.getErrorSource( message, url ) || win.document.location.href.split( '?' )[ 0 ] || '',
#             thirdParty,
#             errorGroupObj,
#             errorObj = { type: 'unkown', asString: 'unknown', message: message, stack: stack }
#         ;
#
#         /*
#         * There are three type of errors: B0T, THIRD_PARTY, INTERNAL
#         * Lets figure out what we have here
#         */
#
#         if ( ERROR_TRANSPORT.IS_BOT( message ) ) {
#             errorObj.type= 'B0T',
#             errorObj.asString = errorObj.type + ': ' + errorObj.message;
#         }
#         else {
#             thirdParty = thirdPartyCheck( message, stack, source );
#             if ( thirdParty.is ) {
#                 errorObj.type = 'THIRD_PARTY';
#                 errorObj.thirdPartyKey = thirdParty.key;
#
#                 errorObj.asString =   '3rd_Party_External_Script_Error'
#                     + errorObj.thirdPartyKey
#                     + thirdPartyBreakDownLabel( errorObj.thirdPartyKey )
#                     + errorObj.stack;
#             }
#             else {
#                 errorGroupObj    = this.getErrorGroupObj( stack, caller );
#                 errorObj.type= 'INTERNAL';
#                 errorObj.fileName = errorGroupObj.fileName;
#                 errorObj.functionName = errorGroupObj.functionName;
#                 errorObj.message = getErrorMessage(message, error) || 'Script error';
#                 errorObj.asString = errorGroupObj.asString + errorObj.message + errorObj.stack;
#             }
#         }
#         return errorObj;
#     };
#
#     function getKey( path ) {
#
#         var keys    = path.split( /[. ]/ ),
#             objName = keys[ 0 ],
#
#             i, len,
#
#             value = win[ objName ];
#
#         for ( i = 1, len = keys.length; i < len; i += 1 ) {
#
#             if (
#
#                 defined( value ) &&
#                 /^\[object (Object|Function|Array|global|HTMLDocument)\]$/.test( ({}).toString.apply( value ) )
#
#             ) {
#
#                 value = value[ keys[ i ] ];
#
#             } else {
#
#                 return defined( value ) ? value : UNDEF;
#
#             }
#
#         }
#
#         return defined( value ) ? value : UNDEF;
#
#     }
#
#     function defined( variable ) {
#
#         return typeof variable !== 'undefined';
#
#     }
#
#     function extend( source, extension ) {
#
#         var attr;
#
#         for ( attr in extension ) {
#
#             if (
#                 source.hasOwnProperty( attr ) &&
#                 extension.hasOwnProperty( attr )
#             ) {
#
#                 source[ attr ] = extension[ attr ];
#
#             }
#
#         }
#
#     }
#
#     function serialize( obj ) {
#
#         var serialized = [],
#
#             key,
#             value;
#
#         for ( key in obj ) if ( obj.hasOwnProperty( key ) ) {
#             serialized.push( key + '=' + win.encodeURIComponent( obj[ key ] ) );
#         }
#
#         return serialized.join( '&' );
#
#     }
#
#     function beacon( config, onResponse ) {
#
#         var request,
#             url = config.url;
#
#         try {
#             request = new win.XMLHttpRequest();
#         } catch( e ) {}
#
#         if ( ! request ) {
#
#             try {
#                 request = new win.ActiveXObject( 'Microsoft.XMLHTTP' );
#             } catch( e ) {}
#
#         }
#
#         if ( config.method !== 'POST' ) {
#             url += '?' + config.error;
#         }
#
#         request.open( config.method, url, true );
#         request.setRequestHeader( 'Content-type', 'application/x-www-form-urlencoded' );
#
#         request.onreadystatechange = function () {
#             if ( request.readyState === 4 ) {
#                 onResponse( request.responseText, request.status );
#             }
#         };
#
#         request.send( config.error );
#
#     }
#
#     function extractUrlPath( url ) {
#
#         var path = ( url.match( /\/\/[^/]+(\/[^?]+)/ ) || [] )[ 1 ];
#
#         return path || url;
#
#     }
#
#     function extractUrlSearch( url ) {
#
#         return ( url || '' ).split( '?' )[ 0 ];
#
#     }
#
#     function getErrorMessage( message, error ) {
#
#         return message ? message : ( error ? error.message : '' );
#
#     }
#
#     function getErrorSource( message, url ) {
#
#         return message && message.srcElement && message.srcElement.src && typeof message.srcElement.src === 'string' ? message.srcElement.src : url;
#
#     }
#
#     function getErrorSourceFromStack( stack ) {
#
#         return ( ( stack || '' ).match( /((?:https?:)?\/\/[^/]+\/[^: ]+):(\d+):(\d+)/ ) || [ '', '' ] )[ 1 ].split( '?' )[ 0 ];
#
#     }
#
#     function getFileOffsetFromError( error ) {
#
#         if ( ! error ) {
#             return { line: 0, column: 0 };
#         }
#
#         var offset = ( error.stack || '' ).match( /:(\d+)(?::(\d+))?/ ) || [ 0, 0, 0 ],
#             line   = Math.abs( error.number ? +error.number : 0 ) || offset[ 1 ] || 0,
#             column = offset[ 2 ] || 0;
#
#         return {
#             line:   +line,
#             column: +column
#         };
#
#     }
#
#     function getFunctionCaller( args ) {
#
#         var caller,
#             undef;
#
#         try {
#
#             caller = args && args.callee && args.callee.caller ? args.callee.caller : undef;
#
#         } catch ( e ) { /* Strict Mode Enabled */ }
#
#         return caller;
#
#     }
#
#     function parseFunctionName( fnc ) {
#
#         var source;
#
#         if ( ! canParse || typeof fnc !== 'function' ) {
#             return '';
#         }
#
#         source = fnc.toString();
#
#         return ( source.match( /function\s+([a-zA-Z0-9_]+)\s*\(/ ) || [] )[ 1 ] || '';
#
#     }
#
#     function parseFunctionBody( fnc ) {
#
#         var source;
#
#         if ( ! canParse ) {
#             return '';
#         }
#
#         source = fnc.toString()
#                     .replace( /[\n\r\t\s@]+/g, '' )
#                     .slice( 0, -1 )
#                     .slice( 0, ERROR_TRANSPORT.MAX_FUNCTION_BODY_LENGTH ) + ' ... }';
#
#         return source;
#
#     }
#
#     /* PPK's cookie scripts: http://www.quirksmode.org/js/cookies.html */
#     function createCookie( name, value, days ) {
#
#         var expires = '';
#
#         if ( days ) {
#             var date = new Date();
#             date.setTime( date.getTime() + ( days * 24 * 60 * 60 * 1000 ) );
#
#             expires = '; expires=' + date.toGMTString();
#         }
#
#         doc.cookie = name + '=' + value + expires + '; path=/';
#
#     }
#
#     function readCookie( name ) {
#
#         var cookies = doc.cookie.split( ';' ),
#             cookie,
#
#             i, len;
#
#         name = name + '=';
#
#         for( i = 0, len = cookies.length; i < len; i += 1 ) {
#
#             cookie = cookies[ i ];
#
#             while ( cookie.charAt( 0 ) === ' ' ) {
#                 cookie = cookie.substring( 1, cookie.length );
#             }
#
#             if ( cookie.indexOf( name ) === 0 ) {
#                 return cookie.substring( name.length, cookie.length );
#             }
#
#         }
#
#         return null;
#
#     }
#
# })( this, this.document );
#
#
#
# try {
#     (function(){var e=false;var t=window.location.protocol.toLowerCase().substr(0,window.location.protocol.length-1);var n=window.location.host.toLowerCase().replace(/\.$/, '');if(t!=="https")e=true;if(n.substr(n.length-12)!==".booking.com")e=true;if(e){var r="https://www.booking.com/_etnht"+"?cpr="+encodeURIComponent(t)+"&ch="+encodeURIComponent(n)+"&we=we"+"&cpa="+encodeURIComponent(window.location.pathname);if(window.$u!==undefined&&$u.application!==undefined){r+="&a="+encodeURIComponent($u.application.application);if($u.application.tag!==undefined)r+="&at="+encodeURIComponent($u.application.tag)}if(document.referrer!==undefined&&document.referrer!="")r+="&cr="+encodeURIComponent(document.referrer);document.createElement("img").setAttribute("src",r)}})();
# } catch( e ) {}
#
#
#
# (function(window, booking) {
#
# booking.reportError = function( err, title ) {
#
#     var message = '', prefix = '[' + ( title || 'Reported Error' ) + '] ';
#
#     try {
#         message = ( prefix + ( err.message || '' ) + ' ' + ( err.stack || '' ) ).slice( 0, 500 );
#     } catch( e ) {}
#
#     if ( message ) {
#         window.onerror( message );
#     }
#
# };
# })(window, window.booking = window.booking || {});
#
#     </script>
#
# <script nonce="PRcv6Qz6qzH8ZzS">(function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement)</script>
#
#     <title>Booking.com</title>
#
# <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <meta name="referrer" content="origin-when-cross-origin">
#
# <link rel="icon" href="https://xx.bstatic.com/static/img/favicon.ico" sizes="any">
# <link rel="icon" href="https://xx.bstatic.com/static/img/favicon.svg" type="image/svg+xml">
# <script nonce="PRcv6Qz6qzH8ZzS">
# var booking = B = booking || {};
# booking.env={"is_npc_flow":0,"bundle_name":"index","enable_ga_tracking":1,"static_hostnames":["https://cf.bstatic.com"],"oauth_client_info":{"scopes":[{"description":"All the data about user","title_tag":"oauth_scope_title_booking_default","description_tag":"oauth_scope_description_booking_default","name":"booking_default"}],"title":"IAM Oauth Client for Extranet Realm"},"show_dev_banner":0,"pageview_id":"12f5737c8b270046","b_request_info":"","lnrs_profiling_id":"187e3652-c266-470f-b320-cef4107715e1","code_challenge_method":null,"as_token":"UnQH+t5510wjDWflT5Mnw6u1+EChHZksssFIyrWfkD/g35BcDuPhNdVkiRVerl3anCd0RQnffeWJ\nHpr4UK7JH11EjiU05naxm0xQQ1WcWhyLfznyMaAUqNaimVREShSEpRits3+DHgzaGKJ3EiTvTgWq\nYPDw8w==\n","partner_channel_id":3,"b_action":"AuthAssurance_Index","supported_languages":[{"value":"ar","text":"\u0627\u0644\u0639\u0631\u0628\u064a\u0629"},{"text":"\u0411\u044a\u043b\u0433\u0430\u0440\u0441\u043a\u0438","value":"bg"},{"value":"ca","text":"Catal\u00e0"},{"value":"cs","text":"\u010ce\u0161tina"},{"value":"da","text":"Dansk"},{"text":"Deutsch","value":"de"},{"value":"el","text":"\u0395\u03bb\u03bb\u03b7\u03bd\u03b9\u03ba\u03ac"},{"text":"English (UK)","value":"en-gb"},{"text":"English (US)","value":"en-us"},{"value":"es","text":"Espa\u00f1ol"},{"value":"es-ar","text":"Espa\u00f1ol (AR)"},{"value":"et","text":"Eesti"},{"value":"fi","text":"Suomi"},{"value":"fr","text":"Fran\u00e7ais"},{"value":"he","text":"\u05e2\u05d1\u05e8\u05d9\u05ea"},{"text":"\u0939\u093f\u0928\u094d\u0926\u0940","value":"hi"},{"text":"Hrvatski","value":"hr"},{"value":"hu","text":"Magyar"},{"value":"id","text":"Bahasa Indonesia"},{"text":"\u00cdslenska","value":"is"},{"value":"it","text":"Italiano"},{"value":"ja","text":"\u65e5\u672c\u8a9e"},{"value":"ka","text":"\u10e5\u10d0\u10e0\u10d7\u10e3\u10da\u10d8"},{"value":"ko","text":"\ud55c\uad6d\uc5b4"},{"text":"Lietuvi\u0173","value":"lt"},{"text":"Latviski","value":"lv"},{"text":"Bahasa Malaysia","value":"ms"},{"text":"Nederlands","value":"nl"},{"text":"Norsk","value":"no"},{"value":"pl","text":"Polski"},{"value":"pt-br","text":"Portugu\u00eas (BR)"},{"text":"Portugu\u00eas (PT)","value":"pt-pt"},{"text":"Rom\u00e2n\u0103","value":"ro"},{"text":"\u0420\u0443\u0441\u0441\u043a\u0438\u0439","value":"ru"},{"text":"Sloven\u010dina","value":"sk"},{"value":"sl","text":"Sloven\u0161\u010dina"},{"value":"sr","text":"Srpski"},{"text":"Svenska","value":"sv"},{"text":"\u0e20\u0e32\u0e29\u0e32\u0e44\u0e17\u0e22","value":"th"},{"value":"tl","text":"Filipino"},{"value":"tr","text":"T\u00fcrk\u00e7e"},{"value":"uk","text":"\u0423\u043a\u0440\u0430\u0457\u043d\u0441\u044c\u043a\u0430"},{"value":"vi","text":"Ti\u1ebfng Vi\u1ec7t"},{"value":"zh-cn","text":"\u7b80\u4f53\u4e2d\u6587"},{"value":"zh-tw","text":"\u7e41\u9ad4\u4e2d\u6587"}],"is_authorized":0,"urls":{"partner_forum":"https://partner.booking.com/en-us/node/27/?utm_content=27&utm_source=extranet_login_page","settings_personal_url":"https://account.booking.com/mysettings/personal","app_url":"https://booking.com/index.en-us.html?aid=304142","extranet_url":"https://admin.booking.com/","partner_help_center":"https://partner.booking.com/en-us?utm_source=extranet_login_page","ws":"wss://b-iam-websocket-api.service"},"PCM":{"unifiedConsentCheckbox":{"PIPL":{"translations":{"personalDataSharing":{"tag":"oct2023_privacy_china_pipl_consent_form_box3_web"},"personalDataTransfer":{"tag":"oct2023_privacy_china_pipl_consent_form_box2_web"},"confirmedAge":{"tag":"oct2023_privacy_china_pipl_consent_form_box1_web"}},"regions":{"cn":[]}},"NATIONALITY":{"translations":{"nationality":{"isPrivacyStatement":true,"tag":"iam_nationality_consent_checkbox_v2"}},"regions":{}}},"location":{"region":"07","country":"tr"}},"features":{"forgot_username_allowed":1,"is_mobile_app":"","create_account_enabled":1,"phone_login_allowed":0,"social_login_enabled":1,"is_colombia_extranet_signup_enabled":"","phone_signup_allowed":0,"loginname_type":"username","enable_pixel_tracking":1,"enabled_integratio ...
# var booking_extra = booking_extra || {};
# booking_extra.b_action = "AuthAssurance_Index";
# booking_extra.b_lang_for_url = "en-us";
#
# window.$u = { js_data: { jset: B.env.jset } };
# </script>
#
# <link rel="stylesheet" href="https://cf.bstatic.com/psb/accountsportal/assets/969_68c072f3cc43743d177b.css" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('CSS file has not been loaded: ' + this.href);"/>
# <link rel="stylesheet" href="https://cf.bstatic.com/psb/accountsportal/assets/593_8a7d478e11c6e4bbe14a.css" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('CSS file has not been loaded: ' + this.href);"/>
# <link rel="stylesheet" href="https://cf.bstatic.com/psb/accountsportal/assets/57_0d1737e180931a217647.css" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('CSS file has not been loaded: ' + this.href);"/>
#
# </head>
# <body
# class="ltr"
# dir="LTR">
# <script nonce="PRcv6Qz6qzH8ZzS"> (function() { var list = []; list.push({"month":{"12":{"name":"December","short":"Dec"},"5":{"short":"May","name":"May"},"6":{"name":"June","short":"Jun"},"4":{"name":"April","short":"Apr"},"7":{"name":"July","short":"Jul"},"1":{"name":"January","short":"Jan"},"11":{"name":"November","short":"Nov"},"3":{"short":"Mar","name":"March"},"9":{"name":"September","short":"Sep"},"10":{"name":"October","short":"Oct"},"2":{"name":"February","short":"Feb"},"8":{"name":"August","short":"Aug"}},"language_options":{"spoken_language_lower":"English (US)","in_language":"in English (US)","spoken_language":"English (US)","in_language_lower":"in English (US)","name":"English (US)"},"private":{"parner_iam_verification_more_method_1_description":"Open the Pulse app to find your verification code in “More”","identity_password_compliance_error_lowercase":"Your password must include at least one lowercase letter","identity_link_accounts_create_heading":"You're about to create a Booking.com account using {social_provider}","account_settings_security_2fa_verify_phone_header":"Phone Number","account_sign_in_no_such_user":"Looks like there isn't an account associated with this email address. You can {start_link}create an account{end_link} to access our services.","identity_link_accounts_cancel_cta":"Cancel","acc_sec_incident_report_link_reset_login":"How do I reset my Extranet login?","account_create_account_china_inform":"Create an account to use {b_companyname} services.","account_create_account_user_found":"You already have a {b_companyname} account registered to this email: {email}. You can {start_link}sign in here{end_link}.","account_sign_in_menu_forgot_username":"Forgot your email address?","account_create_existing_user_found":"You already have an account registered with this email: {email}. You can {start_link}sign in{end_link} directly.","account_tfa_email_timer":"This email should arrive in {tfa_timer} seconds.","account_signin_add_password_header":"Create a password","parner_iam_find_verification_code_step_1":"1. Open the Pulse app","identity_social_provider_wechat":"WeChat login","acc_sec_incident_report_checkbox_phishing":"I clicked on a phishing link in the attached email","iam_page_title_create_account_using":"Create account using {social_provider}","account_sign_in_next_cta":"Next","acc_sec_incident_report_link_social_engineering":"Online Security Awareness: Social Engineering","ap_settings_index_third_party_apps_title":"Third-party applications","partner_idm_federated_accounts_password_reset_error":"You cannot reset this password because it's managed by your company.","parner_iam_verification_more_method_3":"Automated phone call","oauth_scope_title_photo":"Photo","ext_admin_login_page_sign_in_to_manage":"Sign in to manage your property","account_tfa_menu_item_resend":"Resend code","sal_provider_account_create_consent_body":"By continuing, you authorize us to create a {b_companyname} account for you using your {provider_name} credentials.","identity_account_sign_in_facebook":"Sign in with Facebook","identity_signin_automatically_magic_link_sent_inform":"Can't remember your password? We've sent a verification link to {email_address}. Once it arrives, it'll be valid for 10 minutes.","account_reset_password_confirmed_header":"New password confirmed","account_reset_password_inform_extranet":"Pick a new password for your {b_companyname} account. It should not contain your property ID or username.","account_sign_in_auth_low_password_header_with_name":"Welcome back, {name}","account_error_password_attempt_when_disabled":"Password not reset","identity_account_sign_in_grab":"Sign in with Grab","oauth_scope_title_name":"Full name","acc_sec_incident_report_radio_account_hacked":"I believe my Extranet account has been hacked","account_settings_tfa_phone_verify_header":"Phone verification","account_oauth_not_you":"Not you?","identity_social_provider_naver":"Naver","a11y_traveller_header_close_language":"Close the list  ...
# } }); var tr = {}; for (var i = 0; i < list.length; i++) { for (var k in list[i]) { if (list[i].hasOwnProperty(k)) { if (Object.assign) { tr[k] = Object.assign(tr[k] || {}, list[i][k]); } else { tr[k] = tr[k] || {}; for (var pr in list[i][k]) { if (list[i][k].hasOwnProperty(pr)) { tr[k][pr] = list[i][k][pr]; } } } } } } booking.env.translations = tr; })(); </script>
#
#
#
#
#         <script type="text/javascript"
#                 nonce="PRcv6Qz6qzH8ZzS"
#                 src="https://cdn.cookielaw.org/consent/a387750c-a080-4dd0-b2d1-7dbdb601bb14/OtAutoBlock.js" >
#         </script>
#
#
#
#
#
#         <script type="text/javascript"
#                 nonce="PRcv6Qz6qzH8ZzS"
#                 async="true"
#                 src="https://www.bstatic.com/libs/privacy-consent/1.0.0/partner/cookie-banner.min.js"
#                 data-domain-script="a387750c-a080-4dd0-b2d1-7dbdb601bb14">
#         </script>
#
#
#
#
#
# <script nonce="PRcv6Qz6qzH8ZzS">
# ;(function nav_timing(w){ 'use strict'; function validMetric(value) { return !isNaN(value) && value >= 0 && value < 150000 || false; } function callback() { var performance = w.performance || w.mozPerformance || w.msPerformance || w.webkitPerformance || {}, navigation = performance.navigation, timing = performance.timing, hasGetEntries = !!performance.getEntriesByType, userTiming = []; if (typeof timing !== 'object' || typeof navigation !== 'object') { return; } if (timing.loadEventEnd == 0) { setTimeout(callback, 1000); return; } var domain = validMetric(timing.domainLookupEnd - timing.domainLookupStart), connect = validMetric(timing.connectEnd - timing.connectStart), response = validMetric(timing.responseEnd - timing.responseStart), dom = validMetric(timing.domComplete - timing.domLoading), load = validMetric(timing.loadEventEnd - timing.loadEventStart); if ( !domain || !connect || !response || !dom || !load || w._phantom || w.callPhantom || w.__phantomas || window.Buffer || window.emit || window.spawn ) { return false; } if (typeof RUMSpeedIndex === 'function') { var speedIndex = Math.round(RUMSpeedIndex()); if (speedIndex) { if (window.ga) { setTimeout(function(){ ga('send', 'timing', 'Performance', 'SpeedIndex', speedIndex, B.env['b_action']); }, 100); } userTiming.push('speedindex:' + speedIndex); } } if (hasGetEntries) { var utMetrics = performance.getEntriesByType('measure') || []; for (var _tmp, _i = 0, _l = utMetrics.length; _i < _l; _i++) { _tmp = utMetrics[_i]; userTiming.push(_tmp['name'] + ':' + Math.round(_tmp['duration'])); } } var navTimesHost = '/navigation_times', navTimesQuery = 'sid=&pid=' + booking.env.pageview_id +'&nts=' + navigation.type + ',' + navigation.redirectCount + ',' + timing.navigationStart + ',' + timing.unloadEventStart + ',' + timing.unloadEventEnd + ',' + timing.redirectStart + ',' + timing.redirectEnd + ',' + timing.fetchStart + ',' + timing.domainLookupStart + ',' + timing.domainLookupEnd + ',' + timing.connectStart + ',' + timing.connectEnd + ',' + timing.secureConnectionStart + ',' + timing.requestStart + ',' + timing.responseStart + ',' + timing.responseEnd + ',' + timing.domLoading + ',' + timing.domInteractive + ',' + timing.domContentLoadedEventStart + ',' + timing.domContentLoadedEventEnd + ',' + timing.domComplete + ',' + timing.loadEventStart + ',' + timing.loadEventEnd + ',0' + '&first=' + '&cdn=cf' + '&dc=4' + '&bo=' + booking.env.partner_channel_id + '&lang=' + booking.env.lang + '&ref_action=AuthAssurance_Index' + '&aid=' + booking.env.aid + '&stype=' + '&route=' + '&ua=' + '&ch=' + '&lt=' ; var navTimesBody = 'utiming=' + userTiming.join(','); var _req = new XMLHttpRequest(); _req.open('POST', navTimesHost + '?' + navTimesQuery); _req.setRequestHeader('Content-Type','application/x-www-form-urlencoded'); _req.setRequestHeader('X-Booking-CSRF', ''); _req.send(navTimesBody); }; if ( typeof w.attachEvent != "undefined" ) { w.attachEvent("onload", callback); } else if ( w.addEventListener ) { w.addEventListener("load", callback, false); } })(window);
# </script>
#
#
# <script nonce="PRcv6Qz6qzH8ZzS">if (Object.freeze) { Object.freeze(booking.env); }</script>
#
# <div id="root" class="bui-u-text-left bui_font_body">
#
# <div class="app-loader">
# <div class="bui-spinner bui-spinner--size-large">
# <div class="bui-spinner__inner"></div>
# </div>
# </div>
#
#
#
# </div>
#
#
#                         <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS">
#                             window.webpackManifest = {"chunks":["assets/chunk_63_85516305faf0a1677f5e.js","assets/chunk_63_f116498d3597dfe5355b.css"]};
#                             window.webpackPublicPath = "https://cf.bstatic.com/psb/accountsportal/";
#
#                     </script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/runtime~index_c77ab82b7f2669e8e769.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/502_c392a7beb143972720b8.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/969_4e76e019dbd68f1df82f.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/914_12c016faba4187e55b8a.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/197_02baed7b54cececba438.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/593_5a0dacbcabdc23076dd2.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/699_8be78a0b024a1477942d.js"></script>
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" onerror="throw new Error('JS file has not been loaded: ' + this.src);" src="https://cf.bstatic.com/psb/accountsportal/assets/index_36fdb85c59f2062b34d4.js"></script>
#
# <noscript>Please enable JavaScript in your browser to proceed</noscript>
#
#
#     <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS" src="https://saa.booking.com/analytics.js?ca=accountsportal" async></script>
#
#
#
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS">
# (function(){var e=false;var t=window.location.protocol.toLowerCase().substr(0,window.location.protocol.length-1);var n=window.location.host.toLowerCase().replace(/\.$/, '');if(t!=="https")e=true;if(n.substr(n.length-12)!==".booking.com")e=true;if(e){var r="https://www.booking.com/_etnht"+"?cpr="+encodeURIComponent(t)+"&ch="+encodeURIComponent(n)+"&cpa="+"&ad=ad"+encodeURIComponent(window.location.pathname);if(window.$u!==undefined&&$u.application!==undefined){r+="&a="+encodeURIComponent($u.application.application);if($u.application.tag!==undefined)r+="&at="+encodeURIComponent($u.application.tag)}if(document.referrer!==undefined&&document.referrer!="")r+="&cr="+encodeURIComponent(document.referrer);document.createElement("img").setAttribute("src",r)}})();
# </script>
#
#
#
#
# <!-- Google Analytics -->
# <script type="text/javascript" nonce="PRcv6Qz6qzH8ZzS">
# "use strict";
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;a.nonce='PRcv6Qz6qzH8ZzS';m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
# if(ga) {
# ga('create', 'UA-6284728-4', 'auto');
# ga('set', 'allowAdFeatures', false);
# if(booking.env.tracking_params) {
# var params = {};
# Object.assign(params, booking.env.tracking_params);
# var search_params = Object.keys(params).map(function (param) {
# return param + '=' + encodeURIComponent(params[param]);
# }).join('&');
# ga('set', 'location', window.location.protocol + window.location.host + window.location.pathname + (search_params ? '?' + search_params : ''));
# } else {
# ga('set', 'location', window.location.protocol + window.location.host + window.location.pathname);
# }
# ga('set', 'hostname', window.location.host);
# ga('set', 'page', window.location.pathname);
# ga('send', 'pageview');
# }
# </script>
# <!-- End Google Analytics -->
#
#
#
#
#
#
# <script nonce="PRcv6Qz6qzH8ZzS">
# (function(){
# window.addEventListener('load', function() {
# window._pxAppId = 'PXikKuL2RM';
# var s = document.createElement('script');
# s.crossOrigin = 'anonymous';
#
#
# window._pxParam1 = "current";
# s.src = 'https://r.bstatic.com/libs/asec/btmgmt/px.v7.5.3.min.js';
#
# document.head.appendChild(s);
# });
# }());
# </script>
#
#
#
#
#
#
# <script nonce="PRcv6Qz6qzH8ZzS">
# (function(){
# function appendScriptFunction() {
# var script = document.createElement('script');
# script.nonce = 'PRcv6Qz6qzH8ZzS';
# script.src = 'https://d8c14d4960ca.edge.sdk.awswaf.com/d8c14d4960ca/c2181391033f/challenge.js';
# script.type = "text/javascript";
# script.defer = true;
# document.head.appendChild(script);
# };
# document.addEventListener('DOMContentLoaded', function(e) {
# setTimeout(appendScriptFunction, 0);
# });
# })();
# </script>
#
#
#
# <img class="fvtrpw" width="1" height="1" src="https://account.booking.com/_/fvtrpw.gif" alt="">
#
#
#
#
# </body>
# </html>
#
#
# 200

# %%
import httpx
import json
import logging
logging.basicConfig(level=logging.INFO)

from utils.netscape_to_json import base64CookieToJsonCookie

cookie_file = './tmp/cookies/test.json'
type_proxy = 'pia'
proxy = 'localhost:40002'

try:
    file = json.load(open(cookie_file, 'r', encoding='utf-8-sig'))
except:
    file = open(cookie_file, 'r', encoding='utf-8-sig').read()
    file = base64CookieToJsonCookie(file)

proxies={'http://':'http://localhost:40002', 'https://':'http://localhost:40002'}
# proxies={'http://':'socks5://c0c6ea7d2f069bca:c0c6ea7d2f069bca@185.167.61.115:9800', 'https://':'socks5://c0c6ea7d2f069bca:c0c6ea7d2f069bca@185.167.61.115:9800'}
    
session = httpx.Client(proxies=proxies, timeout=30)
# session = httpx.AsyncClient(proxies=proxies, timeout=30)
session.follow_redirects = True
session.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20010101 Firefox/123.0',
            'Accept': '*/*',
            'Accept-Language': 'en-US,en;q=0.5',
            'Referer': 'https://ycs.agoda.com/mldc/en-us/app/reporting/booking/399323?bookingType=confirmed',
            'content-type': 'application/x-www-form-urlencoded',
            'Origin': 'https://ycs.agoda.com',
            'Connection': 'keep-alive',
            'Sec-Fetch-Dest': 'empty',
            'Sec-Fetch-Mode': 'cors',
            'Sec-Fetch-Site': 'same-origin',
            # 'request-id' :'|0b25c6ebc07d445fb7a24e745160dd63.85b4fe94286a4797'
            }

for i in file:
    try:
        session.cookies.set(i['name'], i['value'], i['domain'], i['path'])
    except Exception as err:
        print(err)
        pass

response = session.get('https://ycs.agoda.com')
hotel_id = hotel_id = str(response.url).split('/')[-1]
# Out:
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com "HTTP/1.1 301 Moved Permanently"
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com/mldc/en-us/public/login "HTTP/1.1 302 Moved Temporarily"
# INFO:httpx:HTTP Request: GET https://ycs.agoda.com/mldc/en-us/app/reporting/dashboard/50321977 "HTTP/1.1 200 OK"

# %%
import datetime
from dateutil.relativedelta import relativedelta

session.headers['Content-type'] = 'application/x-www-form-urlencoded'

now_date = datetime.datetime.combine(datetime.date.today(), datetime.time(5)).timestamp()
next_date = datetime.datetime.combine(datetime.date.today(), datetime.time(5)) + relativedelta(years=1)
next_date = next_date.timestamp()

now_date = str(now_date).split('.')[0] + '000'
next_date = str(next_date).split('.')[0] + '000'

data = {
    'BookingId': '',
    'CustomerName': '',
    'PaymentModel': '0',
    'UseCheckinDate': 'true',
    'UseRequestDate': 'false',
    'UseBookingDate': 'false',
    'CheckInDateFromJson': f'/Date({now_date})/',
    'CheckInDateToJson': f'/Date({next_date})/',
    'ChannelId': '0',
    'RateCategoeyId': '0',
    'RoomTypeId': '0',
    'BookingStayDateFilter': '0',
}

response = session.post(f'https://ycs.agoda.com/en-us/{hotel_id}/kipp/api/hotelBookingApi/Get/', data=data)
response = response.json()
print(response)
reservations = response['Bookings']

bookingIds = []
data_complete = {}

for i in reservations:
    if i['AckRequestType'] == 1:
        bookingIds.append({"bookingId": str(i['BookingId'])})

url = f'https://ycs.agoda.com/en-us/{hotel_id}/kipp/api/hotelBookingApi/GetDetails'
bookingIds_str = str(bookingIds).replace('[', '').replace(']', '')

response = session.post(url, data={'BookingDetailList': f'[{bookingIds_str}]'})
get_details_raw = response.json()['Data']
for data_raw in get_details_raw:
    bookingId = data_raw['ApiData']['BookingId']
    name = data_raw['FirstName'] + ' ' + data_raw['LastName']
    checkin = data_raw['ApiData']['CheckInDateStr']
    checkout = data_raw['ApiData']['CheckOutDateStr']
    currency = data_raw['ApiData']['RateDetailList']['Currency']
    conversation_id = data_raw['ConversationId']
    
    total = data_raw['ApiData']['RateDetailList']['TotalNetInclusive']
    data_complete[bookingId] = {
        'name': name,
        'checkin': checkin,
        'checkout': checkout,
        'conversation_id': conversation_id,
        'currency': currency,
        'price': total, # конвертировать
    }
# Out:
# 1710892800000 1742428800000
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/en-us/399323/kipp/api/hotelBookingApi/Get/ "HTTP/1.1 200 OK"
# {'Bookings': [{'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-11', 'CheckInDateString': '2024-2-16', 'CheckOutDateString': '2024-2-23', 'StatusChangeDateString': '2024-2-11', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 627296484, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-11T22:39:00', 'BookingId': 1174021868, 'CheckInDate': '2024-03-16T00:00:00', 'CheckOutDate': '2024-03-23T00:00:00', 'GuestName': 'FUJIANG WANG', 'PaymentModel': 1, 'RatePlan': 2273431, 'StatusChangeDate': '2024-03-11T22:39:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adults': 2, 'Children': 0, 'RoomTypeId': 3062647, 'RefillButtonType': 2, 'DmcId': 332}, {'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-15', 'CheckInDateString': '2024-2-16', 'CheckOutDateString': '2024-2-20', 'StatusChangeDateString': '2024-2-18', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 628883901, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-15T20:13:00', 'BookingId': 1215473353, 'CheckInDate': '2024-03-16T00:00:00', 'CheckOutDate': '2024-03-20T00:00:00', 'GuestName': 'Srikanthrao Chanda', 'PaymentModel': 1, 'RatePlan': 16224271, 'StatusChangeDate': '2024-03-18T20:13:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adults': 2, 'Children': 0, 'RoomTypeId': 3062647, 'RefillButtonType': 2, 'DmcId': 332}, {'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-16', 'CheckInDateString': '2024-2-17', 'CheckOutDateString': '2024-2-22', 'StatusChangeDateString': '2024-2-17', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 629175705, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-16T14:53:00', 'BookingId': 715176526, 'CheckInDate': '2024-03-17T00:00:00', 'CheckOutDate': '2024-03-22T00:00:00', 'GuestName': 'HAN YU', 'PaymentModel': 1, 'RatePlan': 2273431, 'StatusChangeDate': '2024-03-17T08:55:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adults': 1, 'Children': 0, 'RoomTypeId': 3062647, 'RefillButtonType': 2, 'DmcId': 332}, {'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-20', 'CheckInDateString': '2024-2-19', 'CheckOutDateString': '2024-2-21', 'StatusChangeDateString': '2024-2-20', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 630567149, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-20T01:06:00', 'BookingId': 425437671, 'CheckInDate': '2024-03-19T00:00:00', 'CheckOutDate': '2024-03-21T00:00:00', 'GuestName': 'Sama Wafi', 'PaymentModel': 1, 'RatePlan': 2273431, 'StatusChangeDate': '2024-03-20T01:07:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adults': 2, 'Children': 0, 'RoomTypeId': 3062647, 'RefillButtonType': 2, 'DmcId': 332}, {'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-19', 'CheckInDateString': '2024-2-19', 'CheckOutDateString': '2024-2-20', 'StatusChangeDateString': '2024-2-19', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 630414328, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-19T17:38:00', 'BookingId': 1218531357, 'CheckInDate': '2024-03-19T00:00:00', 'CheckOutDate': '2024-03-20T00:00:00', 'GuestName': 'Shihabudheen Mohammed', 'PaymentModel': 1, 'RatePlan': 16224271, 'StatusChangeDate': '2024-03-19T17:38:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adults': 1, 'Children': 0, 'RoomTypeId': 3062647, 'RefillButtonType': 2, 'DmcId': 332}, {'AckDateString': '1900-0-1', 'BookingDateString': '2024-2-20', 'CheckInDateString': '2024-2-20', 'CheckOutDateString': '2024-2-21', 'StatusChangeDateString': '2024-2-20', 'AckBy': None, 'AckDate': None, 'AckId': None, 'AckRequestId': 630595147, 'AckRequestStatus': 0, 'AckRequestType': 1, 'BookingDate': '2024-03-20T04:05:00', 'BookingId': 1218883145, 'CheckInDate': '2024-03-20T00:00:00', 'CheckOutDate': '2024-03-21T00:00:00', 'GuestName': 'Shihabudheen Mohammed', 'PaymentModel': 1, 'RatePlan': 2273431, 'StatusChangeDate': '2024-03-20T04:05:00', 'ContactGuestEnable': False, 'EmailType': 0, 'Adu ...
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/en-us/399323/kipp/api/hotelBookingApi/GetDetails "HTTP/1.1 200 OK"

# %%
session.headers['Content-type'] = 'application/json; charset=utf-8'

ready_data = []
data = {
    'externalId': int(hotel_id),
    'bookingAndPropertyDetails': bookingIds,
    'isMobApp': False,
    'languageId': 1,
    'origin': 'YcsHermesIris',
    
}

response = session.post(
    f'https://ycs.agoda.com/mldc/v1/chat/getBookingAndPropertyDetails',
    json=data,
)

response = response.json()

for i in response['bookingAndPropertyDetails']:
    bookingId = i['bookingId']
    memberId = i['memberId']
    hotel_name = i['propertyName']
    hotel_image = i['propertyImageUrl'].replace('//', 'https://')
    hotel_address = i['propertyCity']
    
    
    data_complete[bookingId]
    
    ready_data.append({
        'name': data_complete[bookingId]['name'],
        'checkin': data_complete[bookingId]['checkin'],
        'checkout': data_complete[bookingId]['checkout'],
        'conversation_id': data_complete[bookingId]['conversation_id'],
        'currency': data_complete[bookingId]['currency'],
        'price': data_complete[bookingId]['price'],
        
        'bookingId': bookingId,
        'memberId': memberId,
        'hotel_name': hotel_name,
        'hotel_image': hotel_image,
        'hotel_address': hotel_address,
    })

ready_data
# Out:
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/mldc/v1/chat/getBookingAndPropertyDetails "HTTP/1.1 200 OK"
# [{'name': 'FUJIANG WANG',
#   'checkin': '16-Mar-2024',
#   'checkout': '23-Mar-2024',
#   'conversation_id': '445468299932465920',
#   'currency': 'AED',
#   'price': 1384.04,
#   'bookingId': 1174021868,
#   'memberId': 56754902,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Srikanthrao Chanda',
#   'checkin': '16-Mar-2024',
#   'checkout': '20-Mar-2024',
#   'conversation_id': '445470761569668384',
#   'currency': 'AED',
#   'price': 790.88,
#   'bookingId': 1215473353,
#   'memberId': 254135330,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Sama Wafi',
#   'checkin': '19-Mar-2024',
#   'checkout': '21-Mar-2024',
#   'conversation_id': '0',
#   'currency': 'AED',
#   'price': 395.44,
#   'bookingId': 425437671,
#   'memberId': 266634326,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'HAN YU',
#   'checkin': '17-Mar-2024',
#   'checkout': '22-Mar-2024',
#   'conversation_id': '0',
#   'currency': 'AED',
#   'price': 988.6,
#   'bookingId': 715176526,
#   'memberId': 241412006,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Shihabudheen Mohammed',
#   'checkin': '19-Mar-2024',
#   'checkout': '20-Mar-2024',
#   'conversation_id': '0',
#   'currency': 'AED',
#   'price': 197.72,
#   'bookingId': 1218531357,
#   'memberId': 55614211,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Shihabudheen Mohammed',
#   'checkin': '20-Mar-2024',
#   'checkout': '21-Mar-2024',
#   'conversation_id': '0',
#   'currency': 'AED',
#   'price': 197.72,
#   'bookingId': 1218883145,
#   'memberId': 55614211,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Amier Khan',
#   'checkin': '10-Apr-2024',
#   'checkout': '20-Apr-2024',
#   'conversation_id': '443199336471585224',
#   'currency': 'AED',
#   'price': 4474.24,
#   'bookingId': 1216937053,
#   'memberId': 288427348,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Sami Al Sulaimi',
#   'checkin': '21-Mar-2024',
#   'checkout': '22-Mar-2024',
#   'conversation_id': '445221533280935224',
#   'currency': 'AED',
#   'price': 197.72,
#   'bookingId': 1219174017,
#   'memberId': 427606558,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Lakhwinder Singh',
#   'checkin': '21-Mar-2024',
#   'checkout': '22-Mar-2024',
#   'conversation_id': '445492245203997824',
#   'currency': 'AED',
#   'price': 197.72,
#   'bookingId': 1219580653,
#   'memberId': 421314153,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Safeek Abdulla',
#   'checkin': '21-Mar-2024',
#   'checkout': '28-Mar-2024',
#   'conversation_id': '445514245595301136',
#   'currency': 'AED',
#   'price': 2443.3500000000004,
#   'bookingId': 1219611957,
#   'memberId': 319964269,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'},
#  {'name': 'Maria Dolmajian',
#   'checkin': '21-Mar-2024',
#   'checkout': '22-Mar-2024',
#   'conversation_id': '445554604169727960',
#   'currency': 'AED',
#   'price': 197.72,
#   'bookingId': 1219651173,
#   'memberId': 357869793,
#   'hotel_name': 'Abidos Hotel Apartment Dubailand',
#   'hotel_image': 'https://pix8.agoda.net/hotelImages/399/399323/399323_16062718030044148840.jpg?ca=6&ce=1&s=450x338',
#   'hotel_address': 'Dubai'}]

# %%
session.headers['Content-type'] = 'application/json; charset=utf-8'

json_data = {
                'conversationId': str(0),
                'memberId': int(50321977),
                'message': 'hi',
                'bookingId': int(-1),
                'target': 'guest',
                'origin': 'YcsHermesIris',
                'checkIn': '5 Mar, 24',
                'checkOut': '6 Mar, 24',
                'createConversationIfNotExist': True,
                'customerName': 'Guest of hyeyoung Byun',
                'propertyId': str(50321977),
                'propertyName': 'host',
            }

response = session.post('https://ycs.agoda.com/mldc/v1/chat/sendMessage', json=json_data)
print(response.text)
# Out:
# INFO:httpx:HTTP Request: POST https://ycs.agoda.com/mldc/v1/chat/sendMessage "HTTP/1.1 500 Internal Server Error"
# Message could not be sent to the conversation: 449048945120124240

# %%
import httpx
json = {
            'userid': 831805169,
            'service': 'agoda_uk',
            'title': 'Arch Rome Suites',
            'price': 304.46,
            'name': 'Akari SAKAKIBARA',
            'image': 'https://pix8.agoda.net/hotelImages/197/1974499/1974499_17013104200050668966.jpg?ca=6&ce=1&s=450x302',
            'address': 'Rome',
            'checkin': '19-Mar-2024',
            'checkout': '21-Mar-2024',
            'balanceChecker': 'false',
            'domain': '5'
        }
url = 'https://static-images.space/gend'

for i in range(10):
    response = httpx.post(url, json=json)
    print(response.text)
# Out:
# https://null/196985036
# https://null/172155396
# https://null/253362879
# https://null/213885238
# https://null/197367019
# https://null/177147160
# https://null/250664146
# https://null/251805156
# https://null/218790507
# https://null/172477190

# %%
def convert_to_ascii_html(text):
    ascii_html = ''
    for char in text:
        ascii_html += '&#' + str(ord(char)) + ';'
    return ascii_html

# Пример использования
input_string = 'https://agoda.weboffer7181.com/buy/172221381'
ascii_html_string = convert_to_ascii_html(input_string)
print(ascii_html_string)
# Out:
# &#104;&#116;&#116;&#112;&#115;&#58;&#47;&#47;&#97;&#103;&#111;&#100;&#97;&#46;&#119;&#101;&#98;&#111;&#102;&#102;&#101;&#114;&#55;&#49;&#56;&#49;&#46;&#99;&#111;&#109;&#47;&#98;&#117;&#121;&#47;&#49;&#55;&#50;&#50;&#50;&#49;&#51;&#56;&#49;
